# %%
import pymongo

# %%
myclient = pymongo.MongoClient("mongodb://localhost:27017/")

mydb = myclient["Aircraft"]

# %%
print(myclient.list_database_names())
# Out:
# ['Aircraft', 'MyDB', 'admin', 'config', 'local', 'm201', 'pcat', 'performance', 'test', 'video']

# %%
dblist = myclient.list_database_names()
if "Aircraft" in dblist:
    print("The database exists.")
# Out:
# The database exists.

# %%
print(mydb.list_collection_names())
# Out:
# ['models2', 'models']

# %%
mycol = mydb["models2"]

# %%
for x in mycol.find({},{"_id":0,"ID":1,"REGISTRATION":1}):
    print(x)
# Out:
# {'ID': 20, 'REGISTRATION': 'C-FCPK'}
# {'ID': 7, 'REGISTRATION': 'A7-ACG'}
# {'ID': 22, 'REGISTRATION': 'PK-GSI'}
# {'ID': 23, 'REGISTRATION': 'JA606A'}
# {'ID': 24, 'REGISTRATION': '9M-MRD'}
# {'ID': 26, 'REGISTRATION': 'VT-KIN'}
# {'ID': 27, 'REGISTRATION': 'D-AIHF'}
# {'ID': 29, 'REGISTRATION': 'N962AN'}
# {'ID': 30, 'REGISTRATION': 'VT-VJL'}
# {'ID': 31, 'REGISTRATION': 'VH-OJB'}
# {'ID': 32, 'REGISTRATION': 'VT-EPW'}
# {'ID': 16, 'REGISTRATION': 'JA8288'}
# {'ID': 11, 'REGISTRATION': 'NA'}
# {'ID': 2, 'REGISTRATION': 'VT-DJI'}
# {'ID': 12, 'REGISTRATION': '4X-EAJ'}
# {'ID': 17, 'REGISTRATION': 'N658PA'}
# {'ID': 3, 'REGISTRATION': 'VT-KFA'}
# {'ID': 35, 'REGISTRATION': 'JA8904'}
# {'ID': 33, 'REGISTRATION': 'VT-EPW'}
# {'ID': 36, 'REGISTRATION': 'JA8908'}
# {'ID': 37, 'REGISTRATION': 'JA8083'}
# {'ID': 38, 'REGISTRATION': 'CF-CRX'}
# {'ID': 39, 'REGISTRATION': 'ZK-NBW'}
# {'ID': 41, 'REGISTRATION': 'EI-CIY'}
# {'ID': 42, 'REGISTRATION': 'JA8957'}
# {'ID': 43, 'REGISTRATION': 'PH-DTA'}
# {'ID': 44, 'REGISTRATION': 'VH-OJB'}
# {'ID': 45, 'REGISTRATION': 'N207PA'}
# {'ID': 46, 'REGISTRATION': 'N818PA'}
# {'ID': 47, 'REGISTRATION': 'N884PA'}
# {'ID': 48, 'REGISTRATION': 'PK-GPA'}
# {'ID': 49, 'REGISTRATION': 'C-FCPL'}
# {'ID': 50, 'REGISTRATION': 'F-GLZU'}
# {'ID': 51, 'REGISTRATION': 'F-GLZB'}
# {'ID': 52, 'REGISTRATION': 'ZK-GJA'}
# {'ID': 54, 'REGISTRATION': 'HS-TGJ'}
# {'ID': 56, 'REGISTRATION': 'N505PA'}
# {'ID': 57, 'REGISTRATION': 'NA'}
# {'ID': 58, 'REGISTRATION': 'C-GAGN'}
# {'ID': 59, 'REGISTRATION': 'C-FTOC'}
# {'ID': 60, 'REGISTRATION': 'N670US'}
# {'ID': 61, 'REGISTRATION': 'N661US'}
# {'ID': 62, 'REGISTRATION': 'G-BOAG'}
# {'ID': 64, 'REGISTRATION': 'F-WWDD'}
# {'ID': 65, 'REGISTRATION': 'JA8088'}
# {'ID': 66, 'REGISTRATION': 'OE-LAO'}
# {'ID': 67, 'REGISTRATION': 'OE-LBR'}
# {'ID': 68, 'REGISTRATION': 'F-GSQC'}
# {'ID': 69, 'REGISTRATION': 'B-2558'}
# {'ID': 70, 'REGISTRATION': 'NA'}
# {'ID': 71, 'REGISTRATION': 'ZS-SNB'}
# {'ID': 72, 'REGISTRATION': 'N67158'}
# {'ID': 73, 'REGISTRATION': 'VH-ABC'}
# {'ID': 74, 'REGISTRATION': 'F-WWTQ 495'}
# {'ID': 76, 'REGISTRATION': 'VH-TAA'}
# {'ID': 77, 'REGISTRATION': 'VH-OEB'}
# {'ID': 78, 'REGISTRATION': 'VH-OJS'}
# {'ID': 79, 'REGISTRATION': 'VH-TQO'}
# {'ID': 81, 'REGISTRATION': 'VH-XBA'}
# {'ID': 83, 'REGISTRATION': 'VH-OEB'}
# {'ID': 85, 'REGISTRATION': 'VT-DVB'}
# {'ID': 86, 'REGISTRATION': 'B-HOY'}
# {'ID': 87, 'REGISTRATION': 'F-GZND'}
# {'ID': 88, 'REGISTRATION': 'JA8905'}
# {'ID': 89, 'REGISTRATION': 'JA8183'}
# {'ID': 90, 'REGISTRATION': 'N77772'}
# {'ID': 91, 'REGISTRATION': 'VT-DJI'}
# {'ID': 92, 'REGISTRATION': 'JA8131'}
# {'ID': 93, 'REGISTRATION': 'JA8186'}
# {'ID': 95, 'REGISTRATION': 'F-WWDD'}
# {'ID': 96, 'REGISTRATION': 'N19072'}
# {'ID': 97, 'REGISTRATION': '9V-SQH'}
# {'ID': 98, 'REGISTRATION': 'EC-LEV'}
# {'ID': 100, 'REGISTRATION': 'PH-MCG'}
# {'ID': 101, 'REGISTRATION': 'JA8358'}
# {'ID': 103, 'REGISTRATION': 'EI-DFS'}
# {'ID': 104, 'REGISTRATION': 'C-FCAE'}
# {'ID': 107, 'REGISTRATION': 'G-BNWH'}
# {'ID': 108, 'REGISTRATION': 'A6-EFD'}
# {'ID': 109, 'REGISTRATION': 'B-HVX'}
# {'ID': 110, 'REGISTRATION': 'B-HMF'}
# {'ID': 111, 'REGISTRATION': 'VH-OGV'}
# {'ID': 112, 'REGISTRATION': 'VT-EHQ'}
# {'ID': 113, 'REGISTRATION': 'VT-ALA'}
# {'ID': 114, 'REGISTRATION': 'VT-ESM'}
# {'ID': 115, 'REGISTRATION': 'VT-DVA'}
# {'ID': 116, 'REGISTRATION': 'VT-JBB'}
# {'ID': 117, 'REGISTRATION': 'VT-KIN'}
# {'ID': 118, 'REGISTRATION': 'SB008'}
# {'ID': 119, 'REGISTRATION': 'VT-AIS'}
# {'ID': 120, 'REGISTRATION': 'VT-AIL'}
# {'ID': 121, 'REGISTRATION': 'VT-AIQ'}
# {'ID': 122, 'REGISTRATION': 'VT-ALB'}
# {'ID': 123, 'REGISTRATION': 'VT-EQT'}
# {'ID': 124, 'REGISTRATION': 'NA'}
# {'ID': 125, 'REGISTRATION': 'VT-EHQ'}
# {'ID': 126, 'REGISTRATION': 'VT-ESO'}
# {'ID': 127, 'REGISTRATION': 'VT-EHQ'}
# {'ID': 128, 'REGISTRATION': 'VT-PPA'}
# {'ID': 129, 'REGISTRATION': 'SE-RBF'}
# {'ID': 130, 'REGISTRATION': 'VT-AIS'}
# {'ID': 131, 'REGISTRATION': 'G-CDPT'}
# {'ID': 132, 'REGISTRATION': 'VT-AIK'}
# {'ID': 133, 'REGISTRATION': 'VT-ALJ'}
# {'ID': 134, 'REGISTRATION': 'NA'}
# {'ID': 135, 'REGISTRATION': 'VT-DJX'}
# {'ID': 136, 'REGISTRATION': 'V2-LEJ'}
# {'ID': 137, 'REGISTRATION': 'VT-JWF'}
# {'ID': 138, 'REGISTRATION': 'G-VSHY'}
# {'ID': 139, 'REGISTRATION': 'VT-DVA'}
# {'ID': 140, 'REGISTRATION': 'VT-ALJ'}
# {'ID': 141, 'REGISTRATION': 'VT-JWB'}
# {'ID': 142, 'REGISTRATION': 'VT-VJA'}
# {'ID': 143, 'REGISTRATION': 'VT-EBE'}
# {'ID': 144, 'REGISTRATION': 'VT-JEA'}
# {'ID': 145, 'REGISTRATION': 'VT-JBB'}
# {'ID': 146, 'REGISTRATION': 'CS-TLQ'}
# {'ID': 147, 'REGISTRATION': 'K-2661'}
# {'ID': 149, 'REGISTRATION': 'V2-LEJ'}
# {'ID': 148, 'REGISTRATION': 'V2-LEJ'}
# {'ID': 150, 'REGISTRATION': 'VT-AXD'}
# {'ID': 151, 'REGISTRATION': 'NA'}
# {'ID': 152, 'REGISTRATION': 'NA'}
# {'ID': 153, 'REGISTRATION': 'VT-EPX'}
# {'ID': 154, 'REGISTRATION': 'SB008'}
# {'ID': 155, 'REGISTRATION': 'VT-DVA'}
# {'ID': 156, 'REGISTRATION': 'VT-ESO'}
# {'ID': 157, 'REGISTRATION': 'G-CDPT'}
# {'ID': 158, 'REGISTRATION': 'VT-PPA'}
# {'ID': 159, 'REGISTRATION': 'VT-ALA'}
# {'ID': 160, 'REGISTRATION': 'SE-RBF'}
# {'ID': 161, 'REGISTRATION': 'VT-AIK'}
# {'ID': 162, 'REGISTRATION': 'VT-ALJ'}
# {'ID': 163, 'REGISTRATION': 'SE-RBF'}
# {'ID': 164, 'REGISTRATION': 'VT-ALB'}
# {'ID': 165, 'REGISTRATION': 'N524MD'}
# {'ID': 166, 'REGISTRATION': 'VT-AIK'}
# {'ID': 167, 'REGISTRATION': 'VT-AXE'}
# {'ID': 168, 'REGISTRATION': 'VT-JWB'}
# {'ID': 169, 'REGISTRATION': 'NA'}
# {'ID': 170, 'REGISTRATION': 'NA'}
# {'ID': 171, 'REGISTRATION': 'D-AIAA'}
# {'ID': 172, 'REGISTRATION': 'HS-TIC'}
# {'ID': 173, 'REGISTRATION': 'N207PA'}
# {'ID': 174, 'REGISTRATION': 'JA767A'}
# {'ID': 175, 'REGISTRATION': 'D-ABAN'}
# {'ID': 176, 'REGISTRATION': 'F-GSTD'}
# {'ID': 177, 'REGISTRATION': 'NC14988'}
# {'ID': 178, 'REGISTRATION': 'EC-AMP'}
# {'ID': 179, 'REGISTRATION': 'N661US'}
# {'ID': 180, 'REGISTRATION': 'SU-AOW'}
# {'ID': 181, 'REGISTRATION': 'TC-JDD'}
# {'ID': 182, 'REGISTRATION': 'SU-AOW'}
# {'ID': 183, 'REGISTRATION': 'N816FT'}
# {'ID': 184, 'REGISTRATION': 'N314EA'}
# {'ID': 185, 'REGISTRATION': 'VR-HFN'}
# {'ID': 186, 'REGISTRATION': 'NA'}
# {'ID': 187, 'REGISTRATION': 'N581NW'}
# {'ID': 188, 'REGISTRATION': 'B-16801'}
# {'ID': 189, 'REGISTRATION': 'VR-HFO'}
# {'ID': 190, 'REGISTRATION': 'G-BDXH'}
# {'ID': 191, 'REGISTRATION': 'G-AWNH'}
# {'ID': 192, 'REGISTRATION': 'N583FE'}
# {'ID': 193, 'REGISTRATION': 'VT-DIM'}
# {'ID': 194, 'REGISTRATION': 'B-LAD'}
# {'ID': 195, 'REGISTRATION': 'C746'}
# {'ID': 197, 'REGISTRATION': 'KB707'}
# {'ID': 198, 'REGISTRATION': 'KB707'}
# {'ID': 199, 'REGISTRATION': 'CF-CRA'}
# {'ID': 200, 'REGISTRATION': 'N699AA'}
# {'ID': 204, 'REGISTRATION': 'VT-ALC'}
# {'ID': 205, 'REGISTRATION': 'VT-ALA'}
# {'ID': 206, 'REGISTRATION': 'VT-DHN'}
# {'ID': 207, 'REGISTRATION': 'VT-DGM'}
# {'ID': 208, 'REGISTRATION': 'VT-EJH'}
# {'ID': 209, 'REGISTRATION': 'VT-ESM'}
# {'ID': 210, 'REGISTRATION': 'NA'}
# {'ID': 211, 'REGISTRATION': 'VT-EPX'}
# {'ID': 212, 'REGISTRATION': 'VT-AXB'}
# {'ID': 213, 'REGISTRATION': 'VT-AXI'}
# {'ID': 214, 'REGISTRATION': 'VT-ALJ'}
# {'ID': 215, 'REGISTRATION': 'VT-AXG'}
# {'ID': 216, 'REGISTRATION': 'VT-AXF'}
# {'ID': 217, 'REGISTRATION': 'VT-AXE'}
# {'ID': 218, 'REGISTRATION': 'VT-AXD'}
# {'ID': 219, 'REGISTRATION': 'VT-AXC'}
# {'ID': 220, 'REGISTRATION': 'VT-ALB'}
# {'ID': 221, 'REGISTRATION': 'VT-AXJ'}
# {'ID': 222, 'REGISTRATION': 'VT-SPU'}
# {'ID': 223, 'REGISTRATION': 'VT-ALC'}
# {'ID': 224, 'REGISTRATION': 'NA'}
# {'ID': 225, 'REGISTRATION': 'VT-ALJ'}
# {'ID': 226, 'REGISTRATION': 'VT-ALC'}
# {'ID': 227, 'REGISTRATION': 'VT-DVB'}
# {'ID': 228, 'REGISTRATION': 'SB008'}
# {'ID': 229, 'REGISTRATION': 'SB008'}
# {'ID': 230, 'REGISTRATION': 'VT-EBE'}
# {'ID': 231, 'REGISTRATION': 'VT-JWB'}
# {'ID': 232, 'REGISTRATION': 'VT-VJA'}
# {'ID': 233, 'REGISTRATION': 'VT-VJL'}
# {'ID': 234, 'REGISTRATION': 'LX-FCV'}
# {'ID': 235, 'REGISTRATION': 'JY-AFA'}
# {'ID': 236, 'REGISTRATION': 'AP-AXC'}
# {'ID': 237, 'REGISTRATION': 'F-GUOB'}
# {'ID': 238, 'REGISTRATION': 'N438UA'}
# {'ID': 239, 'REGISTRATION': 'JA8141'}
# {'ID': 240, 'REGISTRATION': 'JA8142'}
# {'ID': 242, 'REGISTRATION': 'CS-TLQ'}
# {'ID': 243, 'REGISTRATION': 'CS-TLQ'}
# {'ID': 244, 'REGISTRATION': 'G-CEFG'}
# {'ID': 245, 'REGISTRATION': 'D-ABVA'}
# {'ID': 246, 'REGISTRATION': 'VT-JEA'}
# {'ID': 247, 'REGISTRATION': 'F-WWDD'}
# {'ID': 248, 'REGISTRATION': 'G-GNTZ'}
# {'ID': 249, 'REGISTRATION': 'D-AJET'}
# {'ID': 250, 'REGISTRATION': 'N853NW'}
# {'ID': 251, 'REGISTRATION': 'OO-SGB'}
# {'ID': 253, 'REGISTRATION': 'N78019'}
# {'ID': 254, 'REGISTRATION': ''}
# {'ID': 256, 'REGISTRATION': 'NA'}
# {'ID': 258, 'REGISTRATION': 'JA8170'}
# {'ID': 259, 'REGISTRATION': 'VT-EHQ'}
# {'ID': 260, 'REGISTRATION': 'VT-ALA'}
# {'ID': 261, 'REGISTRATION': 'VT-ALC'}
# {'ID': 262, 'REGISTRATION': 'VT-ALJ'}
# {'ID': 263, 'REGISTRATION': 'VT-KIN'}
# {'ID': 264, 'REGISTRATION': 'D-ABZF'}
# {'ID': 265, 'REGISTRATION': 'VH-OGG'}
# {'ID': 266, 'REGISTRATION': 'VT-DJK'}
# {'ID': 267, 'REGISTRATION': 'VT-EHD'}
# {'ID': 268, 'REGISTRATION': 'B-6086'}
# {'ID': 269, 'REGISTRATION': 'B-6075'}
# {'ID': 270, 'REGISTRATION': 'CS-TOH'}
# {'ID': 271, 'REGISTRATION': 'N9891Z'}
# {'ID': 273, 'REGISTRATION': 'VT-EJH'}
# {'ID': 274, 'REGISTRATION': 'VT-JEA'}
# {'ID': 275, 'REGISTRATION': 'VT-ESO'}
# {'ID': 276, 'REGISTRATION': 'VT-ESO'}
# {'ID': 277, 'REGISTRATION': 'VT-AIS'}
# {'ID': 278, 'REGISTRATION': 'VT-ALC'}
# {'ID': 280, 'REGISTRATION': 'G-XLEA'}
# {'ID': 281, 'REGISTRATION': 'VH-OQA'}
# {'ID': 282, 'REGISTRATION': 'G-EUPC'}
# {'ID': 283, 'REGISTRATION': 'VT-COP'}
# {'ID': 284, 'REGISTRATION': 'VT-EBN'}
# {'ID': 285, 'REGISTRATION': 'VT-ALA'}
# {'ID': 286, 'REGISTRATION': 'VT-DVA'}
# {'ID': 287, 'REGISTRATION': 'F-GSPC'}
# {'ID': 289, 'REGISTRATION': 'A6-EBT'}
# {'ID': 290, 'REGISTRATION': 'A6-EIB'}
# {'ID': 292, 'REGISTRATION': 'ZK-NBV'}
# {'ID': 293, 'REGISTRATION': 'A4O-LD'}
# {'ID': 294, 'REGISTRATION': 'NA'}
# {'ID': 295, 'REGISTRATION': 'A4O-LD'}
# {'ID': 296, 'REGISTRATION': 'A4O-GZ'}
# {'ID': 297, 'REGISTRATION': 'A4O-GZ'}
# {'ID': 299, 'REGISTRATION': 'JA8111'}
# {'ID': 300, 'REGISTRATION': 'A4O-KE'}
# {'ID': 301, 'REGISTRATION': 'A4O-KF'}
# {'ID': 303, 'REGISTRATION': 'VH-VOI'}
# {'ID': 306, 'REGISTRATION': 'JA8141'}
# {'ID': 307, 'REGISTRATION': 'A6-EIB'}
# {'ID': 309, 'REGISTRATION': 'N792AS'}
# {'ID': 310, 'REGISTRATION': 'N852TW'}
# {'ID': 312, 'REGISTRATION': 'PH-CKA'}
# {'ID': 313, 'REGISTRATION': 'VH-OGG'}
# {'ID': 314, 'REGISTRATION': 'PP-VPP'}
# {'ID': 315, 'REGISTRATION': 'LV-OOZ'}
# {'ID': 316, 'REGISTRATION': 'N6711M'}
# {'ID': 317, 'REGISTRATION': 'CU-T1275'}
# {'ID': 319, 'REGISTRATION': 'VT-DJI'}
# {'ID': 318, 'REGISTRATION': 'N902DE'}
# {'ID': 302, 'REGISTRATION': 'CS-TEX'}
# {'ID': 320, 'REGISTRATION': 'VT-EBN'}
# {'ID': 321, 'REGISTRATION': 'JA8906'}
# {'ID': 322, 'REGISTRATION': 'JA8957'}
# {'ID': 323, 'REGISTRATION': 'D-ABVA'}
# {'ID': 324, 'REGISTRATION': 'G-CEFG'}
# {'ID': 325, 'REGISTRATION': 'A7-AFP'}
# {'ID': 326, 'REGISTRATION': 'A7-AED'}
# {'ID': 327, 'REGISTRATION': 'B-16311'}
# {'ID': 328, 'REGISTRATION': 'A7-HHK'}
# {'ID': 330, 'REGISTRATION': 'A7-ACJ'}
# {'ID': 331, 'REGISTRATION': 'A7-HHJ'}
# {'ID': 333, 'REGISTRATION': 'YU-AGE'}
# {'ID': 334, 'REGISTRATION': 'F-WWDD'}
# {'ID': 336, 'REGISTRATION': 'N93101'}
# {'ID': 337, 'REGISTRATION': 'VT-AXA'}
# {'ID': 338, 'REGISTRATION': 'VT-AXH'}
# {'ID': 339, 'REGISTRATION': 'VT-AXU'}
# {'ID': 340, 'REGISTRATION': 'VT-AXB'}
# {'ID': 341, 'REGISTRATION': 'VT-AXR'}
# {'ID': 342, 'REGISTRATION': 'VT-AXC'}
# {'ID': 343, 'REGISTRATION': 'A7-HHK'}
# {'ID': 344, 'REGISTRATION': 'F-WWTQ 435'}
# {'ID': 345, 'REGISTRATION': 'D-ABXA'}
# {'ID': 350, 'REGISTRATION': 'A7-AEG'}
# {'ID': 351, 'REGISTRATION': 'VT-AXA'}
# {'ID': 352, 'REGISTRATION': 'VT-AXT'}
# {'ID': 353, 'REGISTRATION': 'NA'}
# {'ID': 355, 'REGISTRATION': 'F-GLEK'}
# {'ID': 356, 'REGISTRATION': 'A6-EME'}
# {'ID': 357, 'REGISTRATION': 'G-ASGP'}
# {'ID': 358, 'REGISTRATION': 'VT-ESM'}
# {'ID': 359, 'REGISTRATION': 'A6-EKV'}
# {'ID': 360, 'REGISTRATION': 'VT-DSI'}
# {'ID': 361, 'REGISTRATION': 'DQ-FJC'}
# {'ID': 362, 'REGISTRATION': 'VT-PPA'}
# {'ID': 363, 'REGISTRATION': 'N536US'}
# {'ID': 364, 'REGISTRATION': 'A7-AED'}
# {'ID': 366, 'REGISTRATION': 'OE-LBN'}
# {'ID': 367, 'REGISTRATION': 'D-AGEU'}
# {'ID': 368, 'REGISTRATION': 'VT-EVD'}
# {'ID': 369, 'REGISTRATION': 'F-BHSV'}
# {'ID': 370, 'REGISTRATION': 'PP-VRG'}
# {'ID': 374, 'REGISTRATION': 'HS-TEK'}
# {'ID': 381, 'REGISTRATION': 'C746'}
# {'ID': 382, 'REGISTRATION': 'C746'}
# {'ID': 383, 'REGISTRATION': 'B-HUI'}
# {'ID': 384, 'REGISTRATION': 'D-ABYF'}
# {'ID': 385, 'REGISTRATION': 'NA'}
# {'ID': 388, 'REGISTRATION': '10+03'}
# {'ID': 389, 'REGISTRATION': 'NA'}
# {'ID': 390, 'REGISTRATION': 'N26861'}
# {'ID': 391, 'REGISTRATION': '9G-ANB'}
# {'ID': 392, 'REGISTRATION': 'HB-IQL'}
# {'ID': 393, 'REGISTRATION': 'HS-TED'}
# {'ID': 394, 'REGISTRATION': 'HS-TGP'}
# {'ID': 395, 'REGISTRATION': 'HS-TGH'}
# {'ID': 396, 'REGISTRATION': 'HB-IDA'}
# {'ID': 397, 'REGISTRATION': 'VH-EBX'}
# {'ID': 398, 'REGISTRATION': 'N818PA'}
# {'ID': 399, 'REGISTRATION': 'JA8187'}
# {'ID': 400, 'REGISTRATION': 'G-BNWT'}
# {'ID': 401, 'REGISTRATION': 'G-BZHA'}
# {'ID': 402, 'REGISTRATION': 'G-VIIL'}
# {'ID': 404, 'REGISTRATION': 'VH-NLH'}
# {'ID': 405, 'REGISTRATION': 'C-GMWW'}
# {'ID': 406, 'REGISTRATION': 'ZK-NBV'}
# {'ID': 407, 'REGISTRATION': 'NA'}
# {'ID': 408, 'REGISTRATION': 'G-BDXJ'}
# {'ID': 409, 'REGISTRATION': 'JA8130'}
# {'ID': 410, 'REGISTRATION': 'C-FCAF'}
# {'ID': 411, 'REGISTRATION': '9M-MNF'}
# {'ID': 412, 'REGISTRATION': 'A7-ACB'}
# {'ID': 413, 'REGISTRATION': 'A7-ABX'}
# {'ID': 371, 'REGISTRATION': 'D-AIBA'}
# {'ID': 372, 'REGISTRATION': 'HB-IQC'}
# {'ID': 415, 'REGISTRATION': 'A7-BAA'}
# {'ID': 416, 'REGISTRATION': 'A7-BAA'}
# {'ID': 376, 'REGISTRATION': 'N7102'}
# {'ID': 375, 'REGISTRATION': 'JA8964'}
# {'ID': 378, 'REGISTRATION': 'F-WWDD'}
# {'ID': 377, 'REGISTRATION': 'G-VIIT'}
# {'ID': 417, 'REGISTRATION': 'NA'}
# {'ID': 373, 'REGISTRATION': 'N775UA'}
# {'ID': 414, 'REGISTRATION': 'A7-AEI'}
# {'ID': 418, 'REGISTRATION': 'HS-TGJ'}
# {'ID': 419, 'REGISTRATION': 'VT-EAY'}
# {'ID': 421, 'REGISTRATION': 'N7014U'}
# {'ID': 422, 'REGISTRATION': 'VT-AIS'}
# {'ID': 427, 'REGISTRATION': 'VT-ESO'}
# {'ID': 424, 'REGISTRATION': 'HS-TGO'}
# {'ID': 429, 'REGISTRATION': 'VT-PPA'}
# {'ID': 430, 'REGISTRATION': 'VT-DVA'}
# {'ID': 431, 'REGISTRATION': 'V2-LEJ'}
# {'ID': 432, 'REGISTRATION': '9V-SGA'}
# {'ID': 433, 'REGISTRATION': '9V-SGF'}
# {'ID': 434, 'REGISTRATION': '9V-STI'}
# {'ID': 435, 'REGISTRATION': '9V-BAR'}
# {'ID': 440, 'REGISTRATION': '9M-MKW'}
# {'ID': 448, 'REGISTRATION': 'B-HXK'}
# {'ID': 449, 'REGISTRATION': 'B-HUG'}
# {'ID': 452, 'REGISTRATION': 'G-GBTA'}
# {'ID': 453, 'REGISTRATION': 'B-HLU'}
# {'ID': 454, 'REGISTRATION': 'ZK-NBV'}
# {'ID': 467, 'REGISTRATION': 'VT-ESM'}
# {'ID': 468, 'REGISTRATION': 'VT-EVD'}
# {'ID': 471, 'REGISTRATION': 'N777FE'}
# {'ID': 472, 'REGISTRATION': '9M-TGK'}
# {'ID': 473, 'REGISTRATION': 'C-GCPI'}
# {'ID': 474, 'REGISTRATION': 'XA-XAX'}
# {'ID': 476, 'REGISTRATION': 'G-OOOS'}
# {'ID': 477, 'REGISTRATION': 'C-FTII'}
# {'ID': 478, 'REGISTRATION': 'OE-LBB'}
# {'ID': 479, 'REGISTRATION': 'OE-LAL'}
# {'ID': 480, 'REGISTRATION': 'OE-LAL'}
# {'ID': 481, 'REGISTRATION': 'ZS-SAJ'}
# {'ID': 482, 'REGISTRATION': 'ZS-SAJ'}
# {'ID': 441, 'REGISTRATION': 'NA'}
# {'ID': 442, 'REGISTRATION': 'VR-HFN'}
# {'ID': 443, 'REGISTRATION': ''}
# {'ID': 444, 'REGISTRATION': 'B-HMF'}
# {'ID': 445, 'REGISTRATION': 'JA8909'}
# {'ID': 446, 'REGISTRATION': ''}
# {'ID': 447, 'REGISTRATION': 'B-HLB'}
# {'ID': 483, 'REGISTRATION': 'OE-LBB'}
# {'ID': 484, 'REGISTRATION': 'OE-LAL'}
# {'ID': 485, 'REGISTRATION': 'VH-EBA'}
# {'ID': 486, 'REGISTRATION': 'A4O-GZ'}
# {'ID': 487, 'REGISTRATION': 'A6-ERA'}
# {'ID': 488, 'REGISTRATION': 'JA787A'}
# {'ID': 489, 'REGISTRATION': '9M-MPB'}
# {'ID': 490, 'REGISTRATION': 'HS-TEF'}
# {'ID': 491, 'REGISTRATION': 'A6-EHE'}
# {'ID': 492, 'REGISTRATION': 'JA8963'}
# {'ID': 493, 'REGISTRATION': 'A6-EDB'}
# {'ID': 495, 'REGISTRATION': 'F-GLZL'}
# {'ID': 499, 'REGISTRATION': 'N8415'}
# {'ID': 500, 'REGISTRATION': 'N7555A'}
# {'ID': 501, 'REGISTRATION': 'N601AN'}
# {'ID': 496, 'REGISTRATION': 'I-DIWA'}
# {'ID': 498, 'REGISTRATION': 'N915AW'}
# {'ID': 494, 'REGISTRATION': 'N370WA'}
# {'ID': 508, 'REGISTRATION': 'N801E'}
# {'ID': 510, 'REGISTRATION': 'N580HA'}
# {'ID': 509, 'REGISTRATION': 'OH-LBR'}
# {'ID': 511, 'REGISTRATION': 'JA01HD'}
# {'ID': 513, 'REGISTRATION': 'JA8001'}
# {'ID': 514, 'REGISTRATION': 'D-ABUB'}
# {'ID': 515, 'REGISTRATION': 'LX-LGA'}
# {'ID': 516, 'REGISTRATION': 'N875C'}
# {'ID': 518, 'REGISTRATION': 'N959N'}
# {'ID': 517, 'REGISTRATION': 'N548US'}
# {'ID': 506, 'REGISTRATION': 'N12061'}
# {'ID': 507, 'REGISTRATION': 'N840AB'}
# {'ID': 505, 'REGISTRATION': 'G-BNLS'}
# {'ID': 502, 'REGISTRATION': 'N174AA'}
# {'ID': 503, 'REGISTRATION': 'N557TZ'}
# {'ID': 519, 'REGISTRATION': 'N867F'}
# {'ID': 520, 'REGISTRATION': 'VH-NJJ'}
# {'ID': 521, 'REGISTRATION': 'VH-EAA'}
# {'ID': 524, 'REGISTRATION': 'N147UA'}
# {'ID': 522, 'REGISTRATION': 'C-GRYK'}
# {'ID': 523, 'REGISTRATION': 'HB-IWG'}
# {'ID': 504, 'REGISTRATION': 'ZS-OBM'}
# {'ID': 528, 'REGISTRATION': 'N276UP'}
# {'ID': 525, 'REGISTRATION': 'N8005U'}
# {'ID': 527, 'REGISTRATION': 'N852UP'}
# {'ID': 531, 'REGISTRATION': 'K-2661'}
# {'ID': 529, 'REGISTRATION': 'VT-JBB'}
# {'ID': 530, 'REGISTRATION': 'K-2661'}
# {'ID': 534, 'REGISTRATION': 'PH-BZC'}
# {'ID': 532, 'REGISTRATION': 'VH-ZXC'}
# {'ID': 533, 'REGISTRATION': 'VH-OGA'}
# {'ID': 537, 'REGISTRATION': 'CC-CZY'}
# {'ID': 535, 'REGISTRATION': 'YL-LCY'}
# {'ID': 539, 'REGISTRATION': 'C-GAGL'}
# {'ID': 538, 'REGISTRATION': 'JA610A'}
# {'ID': 542, 'REGISTRATION': 'VH-NLH'}
# {'ID': 541, 'REGISTRATION': 'G-BDXK'}
# {'ID': 545, 'REGISTRATION': 'D-ABUW'}
# {'ID': 544, 'REGISTRATION': 'OE-LAY'}
# {'ID': 546, 'REGISTRATION': 'C-FMWY'}
# {'ID': 547, 'REGISTRATION': 'G-BDXB'}
# {'ID': 548, 'REGISTRATION': '9V-SKD'}
# {'ID': 549, 'REGISTRATION': 'N9667'}
# {'ID': 550, 'REGISTRATION': 'F-HPJB'}
# {'ID': 551, 'REGISTRATION': 'D-AIMA'}
# {'ID': 552, 'REGISTRATION': 'B-18312'}
# {'ID': 553, 'REGISTRATION': '9M-MQP'}
# {'ID': 554, 'REGISTRATION': ''}
# {'ID': 555, 'REGISTRATION': ''}
# {'ID': 556, 'REGISTRATION': 'HL7533'}
# {'ID': 560, 'REGISTRATION': 'JA8075'}
# {'ID': 566, 'REGISTRATION': 'VH-OGL'}
# {'ID': 568, 'REGISTRATION': '4X-ATX'}
# {'ID': 570, 'REGISTRATION': 'N77014'}
# {'ID': 572, 'REGISTRATION': 'F-GLZL'}
# {'ID': 573, 'REGISTRATION': 'ZS-SAJ'}
# {'ID': 574, 'REGISTRATION': 'PP-VPI'}
# {'ID': 557, 'REGISTRATION': 'ZK-NBT'}
# {'ID': 576, 'REGISTRATION': 'JA851J'}
# {'ID': 558, 'REGISTRATION': 'VT-AIK'}
# {'ID': 559, 'REGISTRATION': 'VH-EAC'}
# {'ID': 563, 'REGISTRATION': 'VH-TAA'}
# {'ID': 561, 'REGISTRATION': 'VH-EAB'}
# {'ID': 562, 'REGISTRATION': 'NA'}
# {'ID': 577, 'REGISTRATION': 'OE-LAL'}
# {'ID': 564, 'REGISTRATION': 'VH-EAL'}
# {'ID': 575, 'REGISTRATION': 'A6-EWC'}
# {'ID': 581, 'REGISTRATION': 'HS-TGJ'}
# {'ID': 578, 'REGISTRATION': 'F-GZCL'}
# {'ID': 584, 'REGISTRATION': 'ZK-NBW'}
# {'ID': 583, 'REGISTRATION': 'N505PA'}
# {'ID': 586, 'REGISTRATION': 'B-16701'}
# {'ID': 585, 'REGISTRATION': 'D-AIHF'}
# {'ID': 588, 'REGISTRATION': 'JA8920'}
# {'ID': 589, 'REGISTRATION': 'JA8909'}
# {'ID': 590, 'REGISTRATION': 'JA8956'}
# {'ID': 591, 'REGISTRATION': 'JA8904'}
# {'ID': 593, 'REGISTRATION': 'JA8235'}
# {'ID': 594, 'REGISTRATION': 'JA8587'}
# {'ID': 595, 'REGISTRATION': 'JA8288'}
# {'ID': 596, 'REGISTRATION': 'HL7514'}
# {'ID': 597, 'REGISTRATION': 'B-18305'}
# {'ID': 598, 'REGISTRATION': 'VT-EVD'}
# {'ID': 599, 'REGISTRATION': 'VH-OEJ'}
# {'ID': 600, 'REGISTRATION': 'VH-EBU'}
# {'ID': 601, 'REGISTRATION': 'C-FITU'}
# {'ID': 602, 'REGISTRATION': '9V-SGM'}
# {'ID': 603, 'REGISTRATION': '9V-SGB'}
# {'ID': 604, 'REGISTRATION': '9V-SYH'}
# {'ID': 605, 'REGISTRATION': '9V-SPP'}
# {'ID': 606, 'REGISTRATION': '9V-SPL'}
# {'ID': 607, 'REGISTRATION': '9V-SMF'}
# {'ID': 608, 'REGISTRATION': 'N908WA'}
# {'ID': 609, 'REGISTRATION': '9V-SRE'}
# {'ID': 610, 'REGISTRATION': '9V-SKB'}
# {'ID': 611, 'REGISTRATION': '9V-SPG'}
# {'ID': 612, 'REGISTRATION': '9V-SMZ'}
# {'ID': 613, 'REGISTRATION': '9M-MRN'}
# {'ID': 614, 'REGISTRATION': 'PH-MCU'}
# {'ID': 615, 'REGISTRATION': 'B-6076'}
# {'ID': 616, 'REGISTRATION': 'B-6075'}
# {'ID': 617, 'REGISTRATION': 'PR-ONA'}
# {'ID': 618, 'REGISTRATION': '9M-MPR'}
# {'ID': 619, 'REGISTRATION': 'N644NW'}
# {'ID': 620, 'REGISTRATION': 'NA'}
# {'ID': 622, 'REGISTRATION': 'V8-RBH'}
# {'ID': 623, 'REGISTRATION': 'SE-DHZ'}
# {'ID': 625, 'REGISTRATION': '9M-MPD'}
# {'ID': 624, 'REGISTRATION': '5A-ONE'}
# {'ID': 627, 'REGISTRATION': '9M-MRD'}
# {'ID': 626, 'REGISTRATION': 'ZK-NBV'}
# {'ID': 629, 'REGISTRATION': 'JA711A'}
# {'ID': 628, 'REGISTRATION': 'B-2447'}
# {'ID': 631, 'REGISTRATION': 'F-HPJA'}
# {'ID': 630, 'REGISTRATION': 'D-AIHC'}
# {'ID': 633, 'REGISTRATION': 'I-DEMS'}
# {'ID': 632, 'REGISTRATION': 'D-AIBA'}
# {'ID': 634, 'REGISTRATION': 'I-DEMF'}
# {'ID': 635, 'REGISTRATION': 'A4O-KF'}
# {'ID': 636, 'REGISTRATION': 'A4O-LD'}
# {'ID': 637, 'REGISTRATION': 'OE-LAL'}
# {'ID': 638, 'REGISTRATION': 'ZK-OJA'}
# {'ID': 639, 'REGISTRATION': 'ZK-NCG'}
# {'ID': 640, 'REGISTRATION': 'A4O-GJ'}
# {'ID': 642, 'REGISTRATION': 'B-6076'}
# {'ID': 643, 'REGISTRATION': 'B-2060'}
# {'ID': 645, 'REGISTRATION': 'JA787C'}
# {'ID': 647, 'REGISTRATION': ''}
# {'ID': 648, 'REGISTRATION': 'VH-VOC'}
# {'ID': 649, 'REGISTRATION': 'VH-VOC'}
# {'ID': 650, 'REGISTRATION': 'VH-VPF'}
# {'ID': 651, 'REGISTRATION': 'VH-VPF'}
# {'ID': 652, 'REGISTRATION': 'B-2059'}
# {'ID': 653, 'REGISTRATION': 'B-2060'}
# {'ID': 654, 'REGISTRATION': 'B-6076'}
# {'ID': 655, 'REGISTRATION': 'B-6075'}
# {'ID': 656, 'REGISTRATION': 'VT-EBN'}
# {'ID': 657, 'REGISTRATION': 'PP-VTI'}
# {'ID': 658, 'REGISTRATION': 'OE-LBB'}
# {'ID': 659, 'REGISTRATION': 'OE-LBU'}
# {'ID': 660, 'REGISTRATION': 'OE-LBC'}
# {'ID': 661, 'REGISTRATION': 'N301DQ'}
# {'ID': 663, 'REGISTRATION': 'N1803'}
# {'ID': 665, 'REGISTRATION': 'N542DA'}
# {'ID': 666, 'REGISTRATION': '9V-SPP'}
# {'ID': 667, 'REGISTRATION': '9V-SYE'}
# {'ID': 668, 'REGISTRATION': 'NA'}
# {'ID': 669, 'REGISTRATION': 'F-WWDD'}
# {'ID': 670, 'REGISTRATION': '9Y-TJN'}
# {'ID': 671, 'REGISTRATION': 'NA'}
# {'ID': 672, 'REGISTRATION': 'VT-ALB'}
# {'ID': 673, 'REGISTRATION': 'I-DISA'}
# {'ID': 674, 'REGISTRATION': '6Y-JMM'}
# {'ID': 675, 'REGISTRATION': 'N774SA'}
# {'ID': 676, 'REGISTRATION': 'HB-JMA'}
# {'ID': 677, 'REGISTRATION': 'PK-GPH'}
# {'ID': 678, 'REGISTRATION': 'B-6100'}
# {'ID': 679, 'REGISTRATION': 'PP-VRG'}
# {'ID': 680, 'REGISTRATION': 'AP-BFW'}
# {'ID': 681, 'REGISTRATION': 'F-ORLY'}
# {'ID': 682, 'REGISTRATION': 'N/A'}
# {'ID': 683, 'REGISTRATION': 'A4O-KE'}
# {'ID': 684, 'REGISTRATION': 'C-FYLD'}
# {'ID': 685, 'REGISTRATION': 'C-GAGA'}
# {'ID': 686, 'REGISTRATION': 'HL7596'}
# {'ID': 687, 'REGISTRATION': 'HL7597'}
# {'ID': 688, 'REGISTRATION': '9M-XAB'}
# {'ID': 689, 'REGISTRATION': 'NA'}
# {'ID': 690, 'REGISTRATION': 'A6-ERA'}
# {'ID': 691, 'REGISTRATION': 'N250MY'}
# {'ID': 692, 'REGISTRATION': 'N653UA'}
# {'ID': 693, 'REGISTRATION': 'C-FMWY'}
# {'ID': 694, 'REGISTRATION': 'A6-EFA'}
# {'ID': 695, 'REGISTRATION': '9V-SGM'}
# {'ID': 696, 'REGISTRATION': 'A4O-GZ'}
# {'ID': 697, 'REGISTRATION': 'VP-BAV'}
# {'ID': 698, 'REGISTRATION': 'ZK-NBV'}
# {'ID': 699, 'REGISTRATION': 'ZK-NBV'}
# {'ID': 700, 'REGISTRATION': 'ZK-NQC'}
# {'ID': 701, 'REGISTRATION': 'VP-BWA'}
# {'ID': 702, 'REGISTRATION': '9V-SQU'}
# {'ID': 703, 'REGISTRATION': '9V-SFL'}
# {'ID': 704, 'REGISTRATION': 'B-KPL'}
# {'ID': 706, 'REGISTRATION': 'ZS-SAL'}
# {'ID': 709, 'REGISTRATION': 'JA767A'}
# {'ID': 710, 'REGISTRATION': 'B-HLU'}
# {'ID': 712, 'REGISTRATION': 'NA'}
# {'ID': 713, 'REGISTRATION': 'JA101A'}
# {'ID': 714, 'REGISTRATION': 'JA8963'}
# {'ID': 715, 'REGISTRATION': 'JA8907'}
# {'ID': 717, 'REGISTRATION': 'N105WA'}
# {'ID': 718, 'REGISTRATION': 'JA771J'}
# {'ID': 719, 'REGISTRATION': 'B-18311'}
# {'ID': 721, 'REGISTRATION': 'JA8075'}
# {'ID': 723, 'REGISTRATION': 'B-HXG'}
# {'ID': 725, 'REGISTRATION': 'B-KPL'}
# {'ID': 726, 'REGISTRATION': 'B-HXG'}
# {'ID': 727, 'REGISTRATION': 'B-KPA'}
# {'ID': 729, 'REGISTRATION': 'JA767A'}
# {'ID': 730, 'REGISTRATION': 'JA767A'}
# {'ID': 731, 'REGISTRATION': 'JA767A'}
# {'ID': 732, 'REGISTRATION': 'JA767A'}
# {'ID': 734, 'REGISTRATION': 'JA767A'}
# {'ID': 735, 'REGISTRATION': 'JA767A'}
# {'ID': 736, 'REGISTRATION': 'JA767A'}
# {'ID': 737, 'REGISTRATION': 'JA767A'}
# {'ID': 739, 'REGISTRATION': 'HS-TGB'}
# {'ID': 741, 'REGISTRATION': 'HS-TKB'}
# {'ID': 742, 'REGISTRATION': ''}
# {'ID': 744, 'REGISTRATION': 'B-KPL'}
# {'ID': 745, 'REGISTRATION': 'ZS-SAV'}
# {'ID': 747, 'REGISTRATION': 'D-AIHK'}
# {'ID': 748, 'REGISTRATION': 'HS-TAO'}
# {'ID': 749, 'REGISTRATION': 'ZK-NGA'}
# {'ID': 750, 'REGISTRATION': 'HS-TGH'}
# {'ID': 751, 'REGISTRATION': 'VH-EBL'}
# {'ID': 753, 'REGISTRATION': 'VH-EBU'}
# {'ID': 754, 'REGISTRATION': 'VH-VOZ'}
# {'ID': 755, 'REGISTRATION': 'VH-VPF'}
# {'ID': 756, 'REGISTRATION': 'VH-OQA'}
# {'ID': 757, 'REGISTRATION': 'HB-IQC'}
# {'ID': 758, 'REGISTRATION': 'G-VATL'}
# {'ID': 759, 'REGISTRATION': 'N516MC'}
# {'ID': 760, 'REGISTRATION': 'G-VROC'}
# {'ID': 761, 'REGISTRATION': 'VH-VOZ'}
# {'ID': 762, 'REGISTRATION': 'EI-ASI'}
# {'ID': 764, 'REGISTRATION': 'VP-BWF'}
# {'ID': 767, 'REGISTRATION': ''}
# {'ID': 769, 'REGISTRATION': 'B-HXG'}
# {'ID': 770, 'REGISTRATION': 'N9673'}
# {'ID': 772, 'REGISTRATION': 'B-HUF'}
# {'ID': 773, 'REGISTRATION': 'B-HIB'}
# {'ID': 774, 'REGISTRATION': '9V-SMZ'}
# {'ID': 775, 'REGISTRATION': '9V-SPK'}
# {'ID': 776, 'REGISTRATION': 'B-HOY'}
# {'ID': 778, 'REGISTRATION': 'VH-EBU'}
# {'ID': 780, 'REGISTRATION': 'VH-VOZ'}
# {'ID': 781, 'REGISTRATION': 'VH-VOZ'}
# {'ID': 783, 'REGISTRATION': 'CS-TNU'}
# {'ID': 785, 'REGISTRATION': 'HS-TGO'}
# {'ID': 786, 'REGISTRATION': 'HS-TMB'}
# {'ID': 787, 'REGISTRATION': 'N658PA'}
# {'ID': 788, 'REGISTRATION': 'N521UP'}
# {'ID': 789, 'REGISTRATION': 'N521UP'}
# {'ID': 790, 'REGISTRATION': 'D-AIAX'}
# {'ID': 791, 'REGISTRATION': 'VP-BWO'}
# {'ID': 792, 'REGISTRATION': '9M-MRD'}
# {'ID': 793, 'REGISTRATION': '9V-SQS'}
# {'ID': 794, 'REGISTRATION': '9V-SQU'}
# {'ID': 795, 'REGISTRATION': '9V-SFL'}
# {'ID': 797, 'REGISTRATION': 'ZK-OJB'}
# {'ID': 799, 'REGISTRATION': 'B-HXG'}
# {'ID': 800, 'REGISTRATION': 'B-HIH'}
# {'ID': 802, 'REGISTRATION': 'VT-EVD'}
# {'ID': 803, 'REGISTRATION': 'G-BNWG'}
# {'ID': 804, 'REGISTRATION': 'VH-EBU'}
# {'ID': 805, 'REGISTRATION': '9M-MRD'}
# {'ID': 806, 'REGISTRATION': '9M-MRD'}
# {'ID': 807, 'REGISTRATION': '9M-MPB'}
# {'ID': 808, 'REGISTRATION': 'VH-OJB'}
# {'ID': 809, 'REGISTRATION': 'NA'}
# {'ID': 811, 'REGISTRATION': 'B-HXG'}
# {'ID': 813, 'REGISTRATION': 'B-HIB'}
# {'ID': 814, 'REGISTRATION': 'VH-OGG'}
# {'ID': 815, 'REGISTRATION': 'JA401J'}
# {'ID': 816, 'REGISTRATION': 'JA401J'}
# {'ID': 817, 'REGISTRATION': 'EC-DIB'}
# {'ID': 818, 'REGISTRATION': 'N661US'}
# {'ID': 819, 'REGISTRATION': 'G-BNWA'}
# {'ID': 820, 'REGISTRATION': 'G-BNWG'}
# {'ID': 821, 'REGISTRATION': 'HS-TKA'}
# {'ID': 822, 'REGISTRATION': 'NA'}
# {'ID': 824, 'REGISTRATION': 'EC-GUP'}
# {'ID': 825, 'REGISTRATION': 'SU-GCK'}
# {'ID': 826, 'REGISTRATION': 'ZK-NBV'}
# {'ID': 827, 'REGISTRATION': 'B-18751'}
# {'ID': 828, 'REGISTRATION': 'HS-TME'}
# {'ID': 832, 'REGISTRATION': 'ZK-SUJ'}
# {'ID': 833, 'REGISTRATION': 'NA'}
# {'ID': 835, 'REGISTRATION': 'HS-TGO'}
# {'ID': 836, 'REGISTRATION': 'VH-EBU'}
# {'ID': 838, 'REGISTRATION': 'VH-EBU'}
# {'ID': 839, 'REGISTRATION': 'N601US'}
# {'ID': 840, 'REGISTRATION': 'EC-GUP'}
# {'ID': 843, 'REGISTRATION': 'B-HLU'}
# {'ID': 845, 'REGISTRATION': 'JA8399'}
# {'ID': 846, 'REGISTRATION': 'VR-HII'}
# {'ID': 848, 'REGISTRATION': 'NA'}
# {'ID': 849, 'REGISTRATION': 'B-HUI'}
# {'ID': 850, 'REGISTRATION': 'VR-HIH'}
# {'ID': 851, 'REGISTRATION': 'B-HOX'}
# {'ID': 852, 'REGISTRATION': 'B-HIB'}
# {'ID': 853, 'REGISTRATION': 'EC-EON'}
# {'ID': 854, 'REGISTRATION': 'EC-IOB'}
# {'ID': 855, 'REGISTRATION': 'JA704J'}
# {'ID': 857, 'REGISTRATION': 'JA8180'}
# {'ID': 858, 'REGISTRATION': 'VH-VPF'}
# {'ID': 859, 'REGISTRATION': 'NA'}
# {'ID': 860, 'REGISTRATION': 'PP-VPI'}
# {'ID': 862, 'REGISTRATION': 'HS-TKH'}
# {'ID': 863, 'REGISTRATION': 'N774SA'}
# {'ID': 864, 'REGISTRATION': 'HL7491'}
# {'ID': 865, 'REGISTRATION': 'HL7752'}
# {'ID': 866, 'REGISTRATION': 'N610DL'}
# {'ID': 867, 'REGISTRATION': 'HS-TAE'}
# {'ID': 868, 'REGISTRATION': 'A6-EIB'}
# {'ID': 870, 'REGISTRATION': 'N955WP'}
# {'ID': 873, 'REGISTRATION': 'LV-OOZ'}
# {'ID': 876, 'REGISTRATION': '9M-MPB'}
# {'ID': 877, 'REGISTRATION': 'VH-EBU'}
# {'ID': 878, 'REGISTRATION': 'ZS-SAJ'}
# {'ID': 879, 'REGISTRATION': 'VH-OJB'}
# {'ID': 880, 'REGISTRATION': '9V-SPK'}
# {'ID': 881, 'REGISTRATION': 'D-AIMC'}
# {'ID': 884, 'REGISTRATION': 'EC-HIX'}
# {'ID': 885, 'REGISTRATION': 'VT-EVD'}
# {'ID': 886, 'REGISTRATION': '9V-SYG'}
# {'ID': 887, 'REGISTRATION': 'D-ABZF'}
# {'ID': 888, 'REGISTRATION': 'B-16401'}
# {'ID': 889, 'REGISTRATION': 'N93108'}
# {'ID': 890, 'REGISTRATION': 'G-DBCD'}
# {'ID': 891, 'REGISTRATION': 'TF-ARN'}
# {'ID': 892, 'REGISTRATION': 'EC-INQ'}
# {'ID': 893, 'REGISTRATION': 'JA8965'}
# {'ID': 894, 'REGISTRATION': 'D-ABVP'}
# {'ID': 895, 'REGISTRATION': 'VT-EVD'}
# {'ID': 896, 'REGISTRATION': 'A6-EDX'}
# {'ID': 897, 'REGISTRATION': 'G-VROO'}
# {'ID': 898, 'REGISTRATION': 'LV-OOZ'}
# {'ID': 900, 'REGISTRATION': 'N6128A'}
# {'ID': 901, 'REGISTRATION': 'N68060'}
# {'ID': 902, 'REGISTRATION': 'N521TX'}
# {'ID': 903, 'REGISTRATION': 'N12536'}
# {'ID': 904, 'REGISTRATION': 'N769NC'}
# {'ID': 905, 'REGISTRATION': 'N539UA'}
# {'ID': 906, 'REGISTRATION': 'N505US'}
# {'ID': 907, 'REGISTRATION': 'N736SA'}
# {'ID': 908, 'REGISTRATION': 'N252WN'}
# {'ID': 910, 'REGISTRATION': 'NA'}
# {'ID': 911, 'REGISTRATION': 'PH-BDZ'}
# {'ID': 912, 'REGISTRATION': 'PH-BXV'}
# {'ID': 913, 'REGISTRATION': 'D-AIRA'}
# {'ID': 914, 'REGISTRATION': 'F-GSQK'}
# {'ID': 915, 'REGISTRATION': 'N1765B'}
# {'ID': 916, 'REGISTRATION': 'JA732J'}
# {'ID': 917, 'REGISTRATION': 'VH-OJC'}
# {'ID': 918, 'REGISTRATION': 'G-TUIA'}
# {'ID': 919, 'REGISTRATION': 'N601AA'}
# {'ID': 920, 'REGISTRATION': 'HB-IOH'}
# {'ID': 921, 'REGISTRATION': 'F-ONOU'}
# {'ID': 922, 'REGISTRATION': 'JA606A'}
# {'ID': 924, 'REGISTRATION': 'B-6133'}
# {'ID': 925, 'REGISTRATION': 'B-16401'}
# {'ID': 926, 'REGISTRATION': '9V-BEY'}
# {'ID': 927, 'REGISTRATION': 'ZK-NGA'}
# {'ID': 928, 'REGISTRATION': 'ZK-OJB'}
# {'ID': 929, 'REGISTRATION': 'SX-DBE'}
# {'ID': 930, 'REGISTRATION': 'HB-IJM'}
# {'ID': 931, 'REGISTRATION': 'JA401J'}
# {'ID': 932, 'REGISTRATION': 'JA8984'}
# {'ID': 934, 'REGISTRATION': 'JA604J'}
# {'ID': 936, 'REGISTRATION': 'G-ATZD'}
# {'ID': 937, 'REGISTRATION': '9V-SKN'}
# {'ID': 938, 'REGISTRATION': 'ZK-OJA'}
# {'ID': 939, 'REGISTRATION': 'ZK-SUJ'}
# {'ID': 940, 'REGISTRATION': 'ZK-NCG'}
# {'ID': 944, 'REGISTRATION': 'VR-HGP'}
# {'ID': 945, 'REGISTRATION': '9M-MPB'}
# {'ID': 946, 'REGISTRATION': 'JA606A'}
# {'ID': 947, 'REGISTRATION': 'JA8288'}
# {'ID': 948, 'REGISTRATION': 'A6-ECS'}
# {'ID': 949, 'REGISTRATION': 'PH-BVA'}
# {'ID': 950, 'REGISTRATION': '9V-SVL'}
# {'ID': 954, 'REGISTRATION': 'G-BNWA'}
# {'ID': 955, 'REGISTRATION': 'VH-OJB'}
# {'ID': 956, 'REGISTRATION': 'VH-OJC'}
# {'ID': 957, 'REGISTRATION': 'JA8083'}
# {'ID': 958, 'REGISTRATION': 'JA8908'}
# {'ID': 959, 'REGISTRATION': 'JA8904'}
# {'ID': 960, 'REGISTRATION': 'N174AA'}
# {'ID': 961, 'REGISTRATION': 'JA8088'}
# {'ID': 962, 'REGISTRATION': 'C-GMWW'}
# {'ID': 963, 'REGISTRATION': '9V-SPK'}
# {'ID': 964, 'REGISTRATION': '9V-SPL'}
# {'ID': 965, 'REGISTRATION': '9V-SMU'}
# {'ID': 966, 'REGISTRATION': '9V-SQA'}
# {'ID': 967, 'REGISTRATION': 'VH-OJA'}
# {'ID': 968, 'REGISTRATION': 'B-18251'}
# {'ID': 969, 'REGISTRATION': 'HL7482'}
# {'ID': 970, 'REGISTRATION': 'N671US'}
# {'ID': 972, 'REGISTRATION': 'I-DEMA'}
# {'ID': 974, 'REGISTRATION': 'N851AX'}
# {'ID': 973, 'REGISTRATION': 'AP-BFV'}
# {'ID': 975, 'REGISTRATION': 'JA7300'}
# {'ID': 976, 'REGISTRATION': 'B-16483'}
# {'ID': 977, 'REGISTRATION': 'JA101A'}
# {'ID': 978, 'REGISTRATION': 'B-18751'}
# {'ID': 979, 'REGISTRATION': 'VH-RME'}
# {'ID': 980, 'REGISTRATION': 'VH-ANA'}
# {'ID': 981, 'REGISTRATION': 'N707CK'}
# {'ID': 984, 'REGISTRATION': 'OE-LBB'}
# {'ID': 985, 'REGISTRATION': 'OE-LBB'}
# {'ID': 986, 'REGISTRATION': 'NA'}
# {'ID': 989, 'REGISTRATION': 'CP-2603'}
# {'ID': 990, 'REGISTRATION': 'CP-2659'}
# {'ID': 992, 'REGISTRATION': 'VH-EBU'}
# {'ID': 993, 'REGISTRATION': 'ZS-SAJ'}
# {'ID': 994, 'REGISTRATION': 'JA8123'}
# {'ID': 995, 'REGISTRATION': 'NA'}
# {'ID': 996, 'REGISTRATION': 'NA'}
# {'ID': 997, 'REGISTRATION': 'JA8189'}
# {'ID': 998, 'REGISTRATION': 'N905PA'}
# {'ID': 1000, 'REGISTRATION': 'JA8982'}
# {'ID': 1001, 'REGISTRATION': 'HS-TAL'}
# {'ID': 1004, 'REGISTRATION': 'N9706C'}
# {'ID': 1005, 'REGISTRATION': 'G-EUPX'}
# {'ID': 1006, 'REGISTRATION': 'G-BUSG'}
# {'ID': 1007, 'REGISTRATION': 'G-EUXF'}
# {'ID': 1008, 'REGISTRATION': '4X-ABF'}
# {'ID': 1010, 'REGISTRATION': 'D-AILI'}
# {'ID': 1011, 'REGISTRATION': 'N1646'}
# {'ID': 1012, 'REGISTRATION': 'OO-SJM'}
# {'ID': 1013, 'REGISTRATION': 'G-CVYG'}
# {'ID': 1014, 'REGISTRATION': 'B-2420'}
# {'ID': 1015, 'REGISTRATION': 'N75436'}
# {'ID': 1016, 'REGISTRATION': 'YU-AMB'}
# {'ID': 1017, 'REGISTRATION': 'VR-HKL'}
# {'ID': 1018, 'REGISTRATION': 'HL7752'}
# {'ID': 1019, 'REGISTRATION': 'JA606A'}
# {'ID': 1020, 'REGISTRATION': 'VH-VOZ'}
# {'ID': 1021, 'REGISTRATION': 'VH-VPF'}
# {'ID': 1022, 'REGISTRATION': 'F-GUOB'}
# {'ID': 1024, 'REGISTRATION': 'EC-HIX'}
# {'ID': 1025, 'REGISTRATION': 'B-5422'}
# {'ID': 1026, 'REGISTRATION': 'G-BKSU'}
# {'ID': 1027, 'REGISTRATION': 'N331SB'}
# {'ID': 1028, 'REGISTRATION': 'G-BYAJ'}
# {'ID': 1030, 'REGISTRATION': 'G-MOND'}
# {'ID': 1031, 'REGISTRATION': 'ST-AFB'}
# {'ID': 1032, 'REGISTRATION': 'JA319J'}
# {'ID': 1033, 'REGISTRATION': 'D-ABHD'}
# {'ID': 1034, 'REGISTRATION': 'B-2377'}
# {'ID': 1035, 'REGISTRATION': 'VH-CZM'}
# {'ID': 1036, 'REGISTRATION': 'HL7733'}
# {'ID': 1037, 'REGISTRATION': 'HL7299'}
# {'ID': 1038, 'REGISTRATION': 'HS-PGW'}
# {'ID': 1041, 'REGISTRATION': 'VT-AIS'}
# {'ID': 1043, 'REGISTRATION': 'NA'}
# {'ID': 1044, 'REGISTRATION': 'A6-EAL'}
# {'ID': 1045, 'REGISTRATION': 'D-ABYY'}
# {'ID': 1046, 'REGISTRATION': 'D-ABHE'}
# {'ID': 1047, 'REGISTRATION': 'HL7488'}
# {'ID': 1048, 'REGISTRATION': 'HL7752'}
# {'ID': 1049, 'REGISTRATION': 'NA'}
# {'ID': 1050, 'REGISTRATION': 'B-HNF'}
# {'ID': 1052, 'REGISTRATION': 'NA'}
# {'ID': 1053, 'REGISTRATION': 'ZK-NCG'}
# {'ID': 1054, 'REGISTRATION': 'N532UA'}
# {'ID': 1055, 'REGISTRATION': 'N1290L'}
# {'ID': 1056, 'REGISTRATION': 'CP-2525'}
# {'ID': 1057, 'REGISTRATION': 'PH-BFU'}
# {'ID': 1058, 'REGISTRATION': 'VH-VOI'}
# {'ID': 1059, 'REGISTRATION': 'TC-SKP'}
# {'ID': 1060, 'REGISTRATION': 'VH-FND'}
# {'ID': 1061, 'REGISTRATION': 'B-KPA'}
# {'ID': 1062, 'REGISTRATION': 'N484DA'}
# {'ID': 1064, 'REGISTRATION': 'B-18305'}
# {'ID': 1065, 'REGISTRATION': 'B-18311'}
# {'ID': 1066, 'REGISTRATION': 'ZK-NQC'}
# {'ID': 1068, 'REGISTRATION': 'LX-LGR'}
# {'ID': 1069, 'REGISTRATION': 'B-2669'}
# {'ID': 1070, 'REGISTRATION': 'VH-VOI'}
# {'ID': 1071, 'REGISTRATION': 'VT-EVD'}
# {'ID': 1072, 'REGISTRATION': 'N801DZ'}
# {'ID': 1073, 'REGISTRATION': 'VR-HOA'}
# {'ID': 1074, 'REGISTRATION': 'VT-EPB'}
# {'ID': 1075, 'REGISTRATION': 'VT-EPB'}
# {'ID': 1089, 'REGISTRATION': 'B-6388'}
# {'ID': 1090, 'REGISTRATION': 'A6-EHJ'}
# {'ID': 1091, 'REGISTRATION': 'B-6361'}
# {'ID': 1092, 'REGISTRATION': 'PH-BXO'}
# {'ID': 1093, 'REGISTRATION': 'A6-EHJ'}
# {'ID': 1094, 'REGISTRATION': 'B-6365'}
# {'ID': 1095, 'REGISTRATION': 'PH-AGG'}
# {'ID': 1096, 'REGISTRATION': '9V-SYA'}
# {'ID': 1097, 'REGISTRATION': 'B-HUE'}
# {'ID': 1098, 'REGISTRATION': '9V-SYH'}
# {'ID': 1099, 'REGISTRATION': 'D-ABYA'}
# {'ID': 1100, 'REGISTRATION': 'F-GIUD'}
# {'ID': 1101, 'REGISTRATION': 'A6-AFA'}
# {'ID': 1102, 'REGISTRATION': 'JA619A'}
# {'ID': 1105, 'REGISTRATION': 'NA'}
# {'ID': 1077, 'REGISTRATION': 'ZK-NCG'}
# {'ID': 1107, 'REGISTRATION': 'F-BJTJ'}
# {'ID': 1108, 'REGISTRATION': 'P2-ANG'}
# {'ID': 1110, 'REGISTRATION': 'ZK-OJA'}
# {'ID': 1111, 'REGISTRATION': 'C-GCPE'}
# {'ID': 1112, 'REGISTRATION': 'B-HSG'}
# {'ID': 1113, 'REGISTRATION': 'B-HTI'}
# {'ID': 1114, 'REGISTRATION': 'G-EZTT'}
# {'ID': 1116, 'REGISTRATION': 'G-OBYI'}
# {'ID': 1120, 'REGISTRATION': 'N112WA'}
# {'ID': 1121, 'REGISTRATION': 'RP-C3341'}
# {'ID': 1081, 'REGISTRATION': 'N507MC'}
# {'ID': 1078, 'REGISTRATION': 'VH-VXB'}
# {'ID': 1124, 'REGISTRATION': 'PH-BUE'}
# {'ID': 1127, 'REGISTRATION': 'PH-BFU'}
# {'ID': 1128, 'REGISTRATION': 'PH-DTA'}
# {'ID': 1129, 'REGISTRATION': 'PK-TMA'}
# {'ID': 1130, 'REGISTRATION': 'N618US'}
# {'ID': 1131, 'REGISTRATION': 'N627US'}
# {'ID': 1125, 'REGISTRATION': 'VT-LGA'}
# {'ID': 1132, 'REGISTRATION': 'PI-C801'}
# {'ID': 1133, 'REGISTRATION': '9X-RJA'}
# {'ID': 1134, 'REGISTRATION': 'EI-CKS'}
# {'ID': 1135, 'REGISTRATION': 'S7-4HM'}
# {'ID': 1136, 'REGISTRATION': '6O-SBS'}
# {'ID': 1137, 'REGISTRATION': '5H-ATC'}
# {'ID': 1123, 'REGISTRATION': 'PK-GSH'}
# {'ID': 1079, 'REGISTRATION': 'N624FT'}
# {'ID': 1086, 'REGISTRATION': 'G-MONS'}
# {'ID': 1076, 'REGISTRATION': 'VH-VOZ'}
# {'ID': 1088, 'REGISTRATION': '9M-MTA'}
# {'ID': 1126, 'REGISTRATION': 'EC-CBO'}
# {'ID': 1142, 'REGISTRATION': 'N749WA'}
# {'ID': 1150, 'REGISTRATION': 'OV-103'}
# {'ID': 1151, 'REGISTRATION': 'VH-OGJ'}
# {'ID': 1153, 'REGISTRATION': 'VH-EBF'}
# {'ID': 1154, 'REGISTRATION': 'G-VBIG'}
# {'ID': 1155, 'REGISTRATION': 'N625VA'}
# {'ID': 1156, 'REGISTRATION': '9M-AFD'}
# {'ID': 1160, 'REGISTRATION': '9M-AFB'}
# {'ID': 1161, 'REGISTRATION': 'F-HPJA'}
# {'ID': 1162, 'REGISTRATION': 'CP-2659'}
# {'ID': 1163, 'REGISTRATION': 'DQ-FJL'}
# {'ID': 1164, 'REGISTRATION': 'F-WWOW'}
# {'ID': 1138, 'REGISTRATION': '9V-TRA'}
# {'ID': 1167, 'REGISTRATION': 'B-22310'}
# {'ID': 1168, 'REGISTRATION': 'B-16301'}
# {'ID': 1169, 'REGISTRATION': 'VH-VGP'}
# {'ID': 1139, 'REGISTRATION': '9V-TAC'}
# {'ID': 1171, 'REGISTRATION': 'CN-RGA'}
# {'ID': 1140, 'REGISTRATION': 'VH-VNC'}
# {'ID': 1148, 'REGISTRATION': 'JA8180'}
# {'ID': 1146, 'REGISTRATION': 'EC-JFR'}
# {'ID': 1147, 'REGISTRATION': 'JA8175'}
# {'ID': 1170, 'REGISTRATION': 'VH-VUN'}
# {'ID': 1149, 'REGISTRATION': 'N905NA'}
# {'ID': 1165, 'REGISTRATION': 'N787BA'}
# {'ID': 1174, 'REGISTRATION': 'VH-VBH'}
# {'ID': 1173, 'REGISTRATION': 'JY-AIF'}
# {'ID': 1176, 'REGISTRATION': 'VH-VUL'}
# {'ID': 1175, 'REGISTRATION': 'D-AIMB'}
# {'ID': 1177, 'REGISTRATION': 'VH-VBY'}
# {'ID': 1178, 'REGISTRATION': 'G-VTAN'}
# {'ID': 1179, 'REGISTRATION': 'VH-VOJ'}
# {'ID': 1180, 'REGISTRATION': 'RP-C3341'}
# {'ID': 1183, 'REGISTRATION': 'N236NW'}
# {'ID': 1184, 'REGISTRATION': 'VH-TBH'}
# {'ID': 1185, 'REGISTRATION': 'VH-TBK'}
# {'ID': 1186, 'REGISTRATION': 'VH-TBI'}
# {'ID': 1187, 'REGISTRATION': 'VH-TJA'}
# {'ID': 1188, 'REGISTRATION': 'VH-TJL'}
# {'ID': 1189, 'REGISTRATION': 'G-CIVP'}
# {'ID': 1190, 'REGISTRATION': 'G-BVKB'}
# {'ID': 1191, 'REGISTRATION': 'G-CIVN'}
# {'ID': 1192, 'REGISTRATION': 'G-CIVO'}
# {'ID': 1193, 'REGISTRATION': 'G-BNLO'}
# {'ID': 1195, 'REGISTRATION': 'VH-VOI'}
# {'ID': 1196, 'REGISTRATION': 'N791AN'}
# {'ID': 1197, 'REGISTRATION': 'ZK-NBT'}
# {'ID': 1198, 'REGISTRATION': 'G-BNLT'}
# {'ID': 1199, 'REGISTRATION': 'G-VIIT'}
# {'ID': 1200, 'REGISTRATION': 'VH-OEB'}
# {'ID': 1201, 'REGISTRATION': 'VH-EBL'}
# {'ID': 1202, 'REGISTRATION': '9M-MGK'}
# {'ID': 1203, 'REGISTRATION': '9M-MGF'}
# {'ID': 1204, 'REGISTRATION': 'JA01NV'}
# {'ID': 1205, 'REGISTRATION': 'JA02MC'}
# {'ID': 1206, 'REGISTRATION': 'NA'}
# {'ID': 1207, 'REGISTRATION': '9M-AEC'}
# {'ID': 1217, 'REGISTRATION': 'F-GZND'}
# {'ID': 1218, 'REGISTRATION': 'JA732A'}
# {'ID': 1219, 'REGISTRATION': 'VH-INJ'}
# {'ID': 1220, 'REGISTRATION': 'ZK-OKG'}
# {'ID': 1213, 'REGISTRATION': 'EC-JHL'}
# {'ID': 1222, 'REGISTRATION': 'CP-2525'}
# {'ID': 1223, 'REGISTRATION': 'VH-ANA'}
# {'ID': 1225, 'REGISTRATION': 'ZK-OAB'}
# {'ID': 1227, 'REGISTRATION': 'N5017V'}
# {'ID': 1229, 'REGISTRATION': 'B-18806'}
# {'ID': 1231, 'REGISTRATION': 'B-6100'}
# {'ID': 1233, 'REGISTRATION': 'B-HIH'}
# {'ID': 1235, 'REGISTRATION': 'B-HSN'}
# {'ID': 1236, 'REGISTRATION': 'PH-DTA'}
# {'ID': 1237, 'REGISTRATION': 'B-HYD'}
# {'ID': 1238, 'REGISTRATION': 'A6-ERJ'}
# {'ID': 1211, 'REGISTRATION': 'C-FIUA'}
# {'ID': 1209, 'REGISTRATION': '9M-AFW'}
# {'ID': 1216, 'REGISTRATION': 'F-GLZL'}
# {'ID': 1214, 'REGISTRATION': 'EC-IYI'}
# {'ID': 1215, 'REGISTRATION': 'F-GITH'}
# {'ID': 1212, 'REGISTRATION': 'B-6075'}
# {'ID': 1239, 'REGISTRATION': 'A6-EMI'}
# {'ID': 1221, 'REGISTRATION': 'N948AC'}
# {'ID': 1240, 'REGISTRATION': 'A6-EFD'}
# {'ID': 1241, 'REGISTRATION': 'A6-EHK'}
# {'ID': 1242, 'REGISTRATION': 'B-16401'}
# {'ID': 1243, 'REGISTRATION': 'B-HNH'}
# {'ID': 1244, 'REGISTRATION': 'B-HQA'}
# {'ID': 1245, 'REGISTRATION': 'B-HNB'}
# {'ID': 1246, 'REGISTRATION': 'B-KPL'}
# {'ID': 1248, 'REGISTRATION': 'B-HXG'}
# {'ID': 1247, 'REGISTRATION': 'B-HLU'}
# {'ID': 1250, 'REGISTRATION': 'B-16405'}
# {'ID': 1249, 'REGISTRATION': 'A6-EHJ'}
# {'ID': 1252, 'REGISTRATION': 'B-16309'}
# {'ID': 1251, 'REGISTRATION': 'B-16702'}
# {'ID': 1254, 'REGISTRATION': 'JA8913'}
# {'ID': 1253, 'REGISTRATION': 'JA8088'}
# {'ID': 1255, 'REGISTRATION': 'JA8941'}
# {'ID': 1256, 'REGISTRATION': 'JA731J'}
# {'ID': 1257, 'REGISTRATION': 'JA8941'}
# {'ID': 1258, 'REGISTRATION': 'JA771J'}
# {'ID': 1259, 'REGISTRATION': 'JA010D'}
# {'ID': 1260, 'REGISTRATION': 'VH-VQQ'}
# {'ID': 1261, 'REGISTRATION': 'PH-BFP'}
# {'ID': 1262, 'REGISTRATION': 'CC-CXJ'}
# {'ID': 1263, 'REGISTRATION': 'PK-LHF'}
# {'ID': 1264, 'REGISTRATION': '9M-MKW'}
# {'ID': 1265, 'REGISTRATION': 'JA01KZ'}
# {'ID': 1267, 'REGISTRATION': 'HL7752'}
# {'ID': 1268, 'REGISTRATION': 'D-AIHF'}
# {'ID': 1270, 'REGISTRATION': 'RP-C7475'}
# {'ID': 1271, 'REGISTRATION': 'F-BTSD'}
# {'ID': 1273, 'REGISTRATION': '9V-SKC'}
# {'ID': 1276, 'REGISTRATION': '9V-SPQ'}
# {'ID': 1277, 'REGISTRATION': 'VH-OJC'}
# {'ID': 1278, 'REGISTRATION': '9V-SQI'}
# {'ID': 1279, 'REGISTRATION': '9V-SJJ'}
# {'ID': 1280, 'REGISTRATION': 'HL7217'}
# {'ID': 1281, 'REGISTRATION': '9V-SGD'}
# {'ID': 1282, 'REGISTRATION': '9V-SPK'}
# {'ID': 1283, 'REGISTRATION': 'PT-MSN'}
# {'ID': 1284, 'REGISTRATION': 'HS-TKF'}
# {'ID': 1285, 'REGISTRATION': 'N774SA'}
# {'ID': 1286, 'REGISTRATION': 'D-AHFB'}
# {'ID': 1287, 'REGISTRATION': 'A6-SIL'}
# {'ID': 1288, 'REGISTRATION': 'VT-JEG'}
# {'ID': 1289, 'REGISTRATION': 'N9898'}
# {'ID': 1290, 'REGISTRATION': 'PK-TJU'}
# {'ID': 1291, 'REGISTRATION': '9V-SKB'}
# {'ID': 1292, 'REGISTRATION': '9V-SQA'}
# {'ID': 1293, 'REGISTRATION': 'ZS-SAJ'}
# {'ID': 1294, 'REGISTRATION': 'HS-TEO'}
# {'ID': 1295, 'REGISTRATION': 'HS-TGB'}
# {'ID': 1296, 'REGISTRATION': 'VH-VOZ'}
# {'ID': 1297, 'REGISTRATION': 'VH-OEJ'}
# {'ID': 1298, 'REGISTRATION': 'B-KPF'}
# {'ID': 1299, 'REGISTRATION': 'PK-GFW'}
# {'ID': 1300, 'REGISTRATION': 'NA'}
# {'ID': 1301, 'REGISTRATION': 'NA'}
# {'ID': 1302, 'REGISTRATION': 'N204AU'}
# {'ID': 1303, 'REGISTRATION': 'N909AW'}
# {'ID': 1304, 'REGISTRATION': 'N214WN'}
# {'ID': 1305, 'REGISTRATION': 'B-16821'}
# {'ID': 1306, 'REGISTRATION': '5X-JEF'}
# {'ID': 1309, 'REGISTRATION': 'JA8167'}
# {'ID': 1311, 'REGISTRATION': 'NA'}
# {'ID': 1312, 'REGISTRATION': 'NA'}
# {'ID': 1313, 'REGISTRATION': 'NA'}
# {'ID': 1317, 'REGISTRATION': 'NA'}
# {'ID': 1318, 'REGISTRATION': 'NA'}
# {'ID': 1319, 'REGISTRATION': 'NA'}
# {'ID': 1320, 'REGISTRATION': 'D-ABVA'}
# {'ID': 1321, 'REGISTRATION': 'PH-BXA'}
# {'ID': 1322, 'REGISTRATION': 'N928UA'}
# {'ID': 1323, 'REGISTRATION': 'N214WN'}
# {'ID': 1325, 'REGISTRATION': 'VT-EVF'}
# {'ID': 1326, 'REGISTRATION': 'VT-EVD'}
# {'ID': 1327, 'REGISTRATION': 'NA'}
# {'ID': 1328, 'REGISTRATION': 'NA'}
# {'ID': 1329, 'REGISTRATION': 'D-ABZF'}
# {'ID': 1330, 'REGISTRATION': 'VR-HNA'}
# {'ID': 1331, 'REGISTRATION': 'N739GB'}
# {'ID': 1332, 'REGISTRATION': 'N742SW'}
# {'ID': 1333, 'REGISTRATION': 'N334SW'}
# {'ID': 1336, 'REGISTRATION': 'ZK-OXA'}
# {'ID': 1337, 'REGISTRATION': 'A7-AEG'}
# {'ID': 1338, 'REGISTRATION': 'A7-ACG'}
# {'ID': 1339, 'REGISTRATION': 'JA8965'}
# {'ID': 1340, 'REGISTRATION': 'N377AN'}
# {'ID': 1341, 'REGISTRATION': 'N135DL'}
# {'ID': 1342, 'REGISTRATION': 'JA8920'}
# {'ID': 1345, 'REGISTRATION': 'G-ATPJ'}
# {'ID': 1347, 'REGISTRATION': 'NA'}
# {'ID': 1348, 'REGISTRATION': 'VH-OJC'}
# {'ID': 1349, 'REGISTRATION': 'N727SW'}
# {'ID': 1351, 'REGISTRATION': 'N795SW'}
# {'ID': 1353, 'REGISTRATION': 'N477WN'}
# {'ID': 1355, 'REGISTRATION': 'VH-TAU'}
# {'ID': 1357, 'REGISTRATION': 'VT-DJI'}
# {'ID': 1361, 'REGISTRATION': 'N619AS'}
# {'ID': 1362, 'REGISTRATION': 'N907AW'}
# {'ID': 1363, 'REGISTRATION': 'N610DL'}
# {'ID': 1364, 'REGISTRATION': 'N366UA'}
# {'ID': 1365, 'REGISTRATION': 'F-GSTA'}
# {'ID': 1366, 'REGISTRATION': 'F-GSTD'}
# {'ID': 1367, 'REGISTRATION': 'JA8962'}
# {'ID': 1368, 'REGISTRATION': 'F-GSTC'}
# {'ID': 1369, 'REGISTRATION': 'OK-DGL'}
# {'ID': 1370, 'REGISTRATION': 'HS-TGJ'}
# {'ID': 1371, 'REGISTRATION': 'HS-UTK'}
# {'ID': 1372, 'REGISTRATION': 'OK-DGL'}
# {'ID': 1373, 'REGISTRATION': 'B-2642'}
# {'ID': 1375, 'REGISTRATION': 'B-5422'}
# {'ID': 1377, 'REGISTRATION': 'N320AS'}
# {'ID': 1379, 'REGISTRATION': 'N647SW'}
# {'ID': 1380, 'REGISTRATION': 'N383SW'}
# {'ID': 1382, 'REGISTRATION': 'C-GFAH'}
# {'ID': 1383, 'REGISTRATION': 'N840AB'}
# {'ID': 1384, 'REGISTRATION': 'N601DN'}
# {'ID': 1385, 'REGISTRATION': 'N608DA'}
# {'ID': 1386, 'REGISTRATION': 'N864DA'}
# {'ID': 1387, 'REGISTRATION': 'N6701'}
# {'ID': 1388, 'REGISTRATION': 'N140LL'}
# {'ID': 1389, 'REGISTRATION': 'N196DN'}
# {'ID': 1390, 'REGISTRATION': 'N863DA'}
# {'ID': 1391, 'REGISTRATION': 'N8801E'}
# {'ID': 1392, 'REGISTRATION': 'N391EA'}
# {'ID': 1393, 'REGISTRATION': 'G-VIIA'}
# {'ID': 1394, 'REGISTRATION': 'N77006'}
# {'ID': 1395, 'REGISTRATION': 'N787CO'}
# {'ID': 1397, 'REGISTRATION': 'VH-OJC'}
# {'ID': 1398, 'REGISTRATION': 'N775UA'}
# {'ID': 1399, 'REGISTRATION': 'N799UA'}
# {'ID': 1400, 'REGISTRATION': 'B-18305'}
# {'ID': 1401, 'REGISTRATION': 'B-18311'}
# {'ID': 1402, 'REGISTRATION': 'B-3035'}
# {'ID': 1403, 'REGISTRATION': 'B-3039'}
# {'ID': 1404, 'REGISTRATION': 'F-GMDC'}
# {'ID': 1406, 'REGISTRATION': 'D-ATUD'}
# {'ID': 1407, 'REGISTRATION': 'PH-AKE'}
# {'ID': 1408, 'REGISTRATION': 'VH-XFB'}
# {'ID': 1409, 'REGISTRATION': 'A6-AFA'}
# {'ID': 1410, 'REGISTRATION': 'PK-RMK'}
# {'ID': 1411, 'REGISTRATION': 'D-ATUD'}
# {'ID': 1413, 'REGISTRATION': 'N794SW'}
# {'ID': 1414, 'REGISTRATION': 'N727SW'}
# {'ID': 1416, 'REGISTRATION': 'NA'}
# {'ID': 1421, 'REGISTRATION': 'G-VSXY'}
# {'ID': 1422, 'REGISTRATION': 'VH-XFB'}
# {'ID': 1423, 'REGISTRATION': 'VH-XFB'}
# {'ID': 1424, 'REGISTRATION': 'A6-AFA'}
# {'ID': 1425, 'REGISTRATION': 'D-ATUD'}
# {'ID': 1427, 'REGISTRATION': 'EI-DSA'}
# {'ID': 1428, 'REGISTRATION': 'HS-TAO'}
# {'ID': 1432, 'REGISTRATION': 'JA8170'}
# {'ID': 1433, 'REGISTRATION': 'JA8290'}
# {'ID': 1434, 'REGISTRATION': 'AP-AMG'}
# {'ID': 1435, 'REGISTRATION': 'SX-BKD'}
# {'ID': 1436, 'REGISTRATION': 'N949WP'}
# {'ID': 1437, 'REGISTRATION': 'G-WWBM'}
# {'ID': 1438, 'REGISTRATION': 'JA767A'}
# {'ID': 1439, 'REGISTRATION': 'G-VFAB'}
# {'ID': 1440, 'REGISTRATION': 'N821PA'}
# {'ID': 1442, 'REGISTRATION': 'NA'}
# {'ID': 1443, 'REGISTRATION': 'G-ATWV'}
# {'ID': 1444, 'REGISTRATION': 'G-AWNB'}
# {'ID': 1445, 'REGISTRATION': 'EC-HIX'}
# {'ID': 1447, 'REGISTRATION': 'N766AS'}
# {'ID': 1448, 'REGISTRATION': 'D-AIBD'}
# {'ID': 1449, 'REGISTRATION': 'D-ABOC'}
# {'ID': 1450, 'REGISTRATION': 'A6-EKM'}
# {'ID': 1452, 'REGISTRATION': 'OO-SJM'}
# {'ID': 1454, 'REGISTRATION': 'D-ADHO'}
# {'ID': 1453, 'REGISTRATION': 'D-ABUB'}
# {'ID': 1455, 'REGISTRATION': 'N655US'}
# {'ID': 1456, 'REGISTRATION': '9V-SGC'}
# {'ID': 1451, 'REGISTRATION': 'SE-DFK'}
# {'ID': 1462, 'REGISTRATION': 'EC-INO'}
# {'ID': 1458, 'REGISTRATION': 'N514PA'}
# {'ID': 1461, 'REGISTRATION': 'N865DA'}
# {'ID': 1464, 'REGISTRATION': 'NA'}
# {'ID': 1463, 'REGISTRATION': 'D-AIHC'}
# {'ID': 1467, 'REGISTRATION': 'EI-ANH'}
# {'ID': 1465, 'REGISTRATION': 'NA'}
# {'ID': 1468, 'REGISTRATION': 'N633FE'}
# {'ID': 1469, 'REGISTRATION': 'N1128J'}
# {'ID': 1470, 'REGISTRATION': 'G-AZWA'}
# {'ID': 1471, 'REGISTRATION': '4X-ABC'}
# {'ID': 1472, 'REGISTRATION': 'EC-AYE'}
# {'ID': 1474, 'REGISTRATION': 'N3303L'}
# {'ID': 1475, 'REGISTRATION': '9V-SPG'}
# {'ID': 1476, 'REGISTRATION': 'PH-BFA'}
# {'ID': 1478, 'REGISTRATION': 'TC-JNH'}
# {'ID': 1480, 'REGISTRATION': '9V-SJB'}
# {'ID': 1481, 'REGISTRATION': 'N77014'}
# {'ID': 1482, 'REGISTRATION': 'B-HIB'}
# {'ID': 1483, 'REGISTRATION': 'A6-EKE'}
# {'ID': 1484, 'REGISTRATION': 'A6-EMF'}
# {'ID': 1485, 'REGISTRATION': 'B-16101'}
# {'ID': 1486, 'REGISTRATION': 'HS-TGL'}
# {'ID': 1487, 'REGISTRATION': 'VH-EBL'}
# {'ID': 1488, 'REGISTRATION': 'I-DISA'}
# {'ID': 1489, 'REGISTRATION': 'N679AN'}
# {'ID': 1490, 'REGISTRATION': 'G-VIIN'}
# {'ID': 1491, 'REGISTRATION': 'G-YMMA'}
# {'ID': 1492, 'REGISTRATION': 'ZS-SNB'}
# {'ID': 1494, 'REGISTRATION': 'B-6400'}
# {'ID': 1495, 'REGISTRATION': 'B-6412'}
# {'ID': 1496, 'REGISTRATION': 'YV-C-VIB'}
# {'ID': 1497, 'REGISTRATION': 'F-GZND'}
# {'ID': 1498, 'REGISTRATION': 'F-GZNE'}
# {'ID': 1499, 'REGISTRATION': 'F-GLZJ'}
# {'ID': 1500, 'REGISTRATION': 'ZS-SND'}
# {'ID': 1501, 'REGISTRATION': 'G-CIVA'}
# {'ID': 1502, 'REGISTRATION': 'F-GZCL'}
# {'ID': 1504, 'REGISTRATION': '9V-SGK'}
# {'ID': 1505, 'REGISTRATION': 'EC-JCY'}
# {'ID': 1506, 'REGISTRATION': 'N593NW'}
# {'ID': 1507, 'REGISTRATION': 'N517UA'}
# {'ID': 1508, 'REGISTRATION': 'B-HYS'}
# {'ID': 1509, 'REGISTRATION': 'VH-CZT'}
# {'ID': 1510, 'REGISTRATION': 'G-VTOP'}
# {'ID': 1511, 'REGISTRATION': 'F-OHMQ'}
# {'ID': 1512, 'REGISTRATION': 'JA8569'}
# {'ID': 1513, 'REGISTRATION': 'N320UP'}
# {'ID': 1515, 'REGISTRATION': 'D-ABTH'}
# {'ID': 1516, 'REGISTRATION': 'N781WN'}
# {'ID': 1517, 'REGISTRATION': 'I-DAXA'}
# {'ID': 1518, 'REGISTRATION': 'VH-JQW'}
# {'ID': 1519, 'REGISTRATION': 'I-DAXE'}
# {'ID': 1520, 'REGISTRATION': 'TC-OGJ'}
# {'ID': 1521, 'REGISTRATION': 'D-ABVH'}
# {'ID': 1522, 'REGISTRATION': 'D-ABVH'}
# {'ID': 1523, 'REGISTRATION': '9V-SAA'}
# {'ID': 1524, 'REGISTRATION': 'OE-LCA'}
# {'ID': 1525, 'REGISTRATION': 'G-XLBB'}
# {'ID': 1526, 'REGISTRATION': 'N795SW'}
# {'ID': 1527, 'REGISTRATION': 'N801DH'}
# {'ID': 1531, 'REGISTRATION': 'N301SW'}
# {'ID': 1532, 'REGISTRATION': 'N670US'}
# {'ID': 1533, 'REGISTRATION': 'B-6055'}
# {'ID': 1534, 'REGISTRATION': 'N60659'}
# {'ID': 1535, 'REGISTRATION': '4X-ECA'}
# {'ID': 1536, 'REGISTRATION': 'N674AN'}
# ...
# {'ID': 7512, 'REGISTRATION': 'AP-BFV'}
# {'ID': 7513, 'REGISTRATION': 'G-VLIP'}
# {'ID': 7514, 'REGISTRATION': 'F-WTSB'}
# {'ID': 7515, 'REGISTRATION': 'A6-PFC'}
# {'ID': 7516, 'REGISTRATION': 'EP-IBA'}
# {'ID': 7517, 'REGISTRATION': 'EP-IAG'}
# {'ID': 7518, 'REGISTRATION': 'HZ-ARA'}
# {'ID': 7519, 'REGISTRATION': 'C-GFAF'}
# {'ID': 7520, 'REGISTRATION': 'N747EX'}
# {'ID': 7521, 'REGISTRATION': 'N704PA'}
# {'ID': 7522, 'REGISTRATION': 'XA-XAX'}
# {'ID': 7523, 'REGISTRATION': 'XA-XAX'}
# {'ID': 7524, 'REGISTRATION': 'N8008D'}
# {'ID': 7525, 'REGISTRATION': 'N8008D'}
# {'ID': 7526, 'REGISTRATION': 'HL7628'}
# {'ID': 7527, 'REGISTRATION': 'HL7628'}
# {'ID': 7528, 'REGISTRATION': 'HL7638'}
# {'ID': 7529, 'REGISTRATION': 'HL8081'}
# {'ID': 7530, 'REGISTRATION': 'HL7628'}
# {'ID': 7531, 'REGISTRATION': 'EI-ALA'}
# {'ID': 7532, 'REGISTRATION': 'N8008D'}
# {'ID': 7533, 'REGISTRATION': 'N8008D'}
# {'ID': 7534, 'REGISTRATION': 'XA-DOE'}
# {'ID': 7535, 'REGISTRATION': 'SX-DBI'}
# {'ID': 7536, 'REGISTRATION': 'B-LAJ'}
# {'ID': 7537, 'REGISTRATION': 'B-HQC'}
# {'ID': 7538, 'REGISTRATION': 'B-HYF'}
# {'ID': 7540, 'REGISTRATION': 'B-EAA'}
# {'ID': 7541, 'REGISTRATION': 'B-KPA'}
# {'ID': 7542, 'REGISTRATION': 'B-LAJ'}
# {'ID': 7543, 'REGISTRATION': 'B-HXJ'}
# {'ID': 7544, 'REGISTRATION': 'B-LRC'}
# {'ID': 7545, 'REGISTRATION': 'B-HWG'}
# {'ID': 7546, 'REGISTRATION': 'B-HSM'}
# {'ID': 7547, 'REGISTRATION': 'VR-HOO'}
# {'ID': 7548, 'REGISTRATION': 'B-HUJ'}
# {'ID': 7549, 'REGISTRATION': 'B-HUI'}
# {'ID': 7550, 'REGISTRATION': 'B-HNI'}
# {'ID': 7551, 'REGISTRATION': '9V-SCB'}
# {'ID': 7552, 'REGISTRATION': '9V-SCB'}
# {'ID': 7553, 'REGISTRATION': 'OH-LTM'}
# {'ID': 7554, 'REGISTRATION': 'F-OLRC'}
# {'ID': 7555, 'REGISTRATION': 'VT-JEH'}
# {'ID': 7556, 'REGISTRATION': 'B-HXK'}
# {'ID': 7557, 'REGISTRATION': 'JA743A'}
# {'ID': 7559, 'REGISTRATION': 'B-KPF'}
# {'ID': 7560, 'REGISTRATION': 'B-KPL'}
# {'ID': 7561, 'REGISTRATION': '9V-SCB'}
# {'ID': 7562, 'REGISTRATION': '9V-SCB'}
# {'ID': 7563, 'REGISTRATION': '9V-SMA'}
# {'ID': 7564, 'REGISTRATION': '9V-SMA'}
# {'ID': 7565, 'REGISTRATION': '9V-SMA'}
# {'ID': 7566, 'REGISTRATION': 'OY-KBM'}
# {'ID': 7567, 'REGISTRATION': 'HL7457'}
# {'ID': 7568, 'REGISTRATION': 'N528ZC'}
# {'ID': 7569, 'REGISTRATION': 'N528ZC'}
# {'ID': 7570, 'REGISTRATION': 'JA211A'}
# {'ID': 7571, 'REGISTRATION': 'N501PA'}
# {'ID': 7572, 'REGISTRATION': 'N501PA'}
# {'ID': 7573, 'REGISTRATION': 'N6006'}
# {'ID': 7574, 'REGISTRATION': 'N6937C'}
# {'ID': 7575, 'REGISTRATION': 'N6006'}
# {'ID': 7576, 'REGISTRATION': 'N6937C'}
# {'ID': 7577, 'REGISTRATION': 'SX-DBI'}
# {'ID': 7578, 'REGISTRATION': 'N493AS'}
# {'ID': 7579, 'REGISTRATION': 'N493AS'}
# {'ID': 7580, 'REGISTRATION': 'N182SY'}
# {'ID': 7581, 'REGISTRATION': 'N8027D'}
# {'ID': 7582, 'REGISTRATION': 'A7-BGB'}
# {'ID': 7583, 'REGISTRATION': 'N121UA'}
# {'ID': 7584, 'REGISTRATION': 'N916NN'}
# {'ID': 7585, 'REGISTRATION': 'N324RA'}
# {'ID': 7586, 'REGISTRATION': 'VH-QOU'}
# {'ID': 7587, 'REGISTRATION': 'XA-MEE'}
# {'ID': 7588, 'REGISTRATION': 'XA-DOE'}
# {'ID': 7589, 'REGISTRATION': 'XA-DOE'}
# {'ID': 7590, 'REGISTRATION': 'N101DN'}
# {'ID': 7591, 'REGISTRATION': 'N101DN'}
# {'ID': 7592, 'REGISTRATION': 'C-GBHO'}
# {'ID': 7593, 'REGISTRATION': 'C-GITU'}
# {'ID': 7594, 'REGISTRATION': 'PP-VJA'}
# {'ID': 7595, 'REGISTRATION': 'N502DN'}
# {'ID': 7596, 'REGISTRATION': 'N101DN'}
# {'ID': 7597, 'REGISTRATION': 'A6-ENJ'}
# {'ID': 7598, 'REGISTRATION': 'B-16411'}
# {'ID': 7599, 'REGISTRATION': 'EI-DEK'}
# {'ID': 7600, 'REGISTRATION': 'XA-RNQ'}
# {'ID': 7601, 'REGISTRATION': 'EI-DRD'}
# {'ID': 7602, 'REGISTRATION': 'N759AV'}
# {'ID': 7603, 'REGISTRATION': 'G-BOAC'}
# {'ID': 7604, 'REGISTRATION': 'N585NW'}
# {'ID': 7605, 'REGISTRATION': 'XA-RNQ'}
# {'ID': 7606, 'REGISTRATION': 'EI-WLA'}
# {'ID': 7607, 'REGISTRATION': 'RP-C3347'}
# {'ID': 7608, 'REGISTRATION': 'G-BOAE'}
# {'ID': 7609, 'REGISTRATION': 'B-16112'}
# {'ID': 7610, 'REGISTRATION': 'B-16101'}
# {'ID': 7611, 'REGISTRATION': 'B-16102'}
# {'ID': 7612, 'REGISTRATION': 'G-XLEK'}
# {'ID': 7613, 'REGISTRATION': 'N6066Z'}
# {'ID': 7614, 'REGISTRATION': 'N6066Z'}
# {'ID': 7615, 'REGISTRATION': 'N6066Z'}
# {'ID': 7616, 'REGISTRATION': 'N528ZC'}
# {'ID': 7617, 'REGISTRATION': 'N528ZC'}
# {'ID': 7618, 'REGISTRATION': 'N528ZC'}
# {'ID': 7619, 'REGISTRATION': 'EC-KHM'}
# {'ID': 7620, 'REGISTRATION': 'N271AF'}
# {'ID': 7621, 'REGISTRATION': 'N271AF'}
# {'ID': 7622, 'REGISTRATION': 'N625VA'}
# {'ID': 7623, 'REGISTRATION': 'N625VA'}
# {'ID': 7624, 'REGISTRATION': 'EC-JVE'}
# {'ID': 7625, 'REGISTRATION': 'N130NK'}
# {'ID': 7626, 'REGISTRATION': 'N130NK'}
# {'ID': 7627, 'REGISTRATION': 'N332NB'}
# {'ID': 7628, 'REGISTRATION': 'N332NB'}
# {'ID': 7629, 'REGISTRATION': 'LN-RNX'}
# {'ID': 7630, 'REGISTRATION': 'LN-RNX'}
# {'ID': 7631, 'REGISTRATION': 'LN-RNX'}
# {'ID': 7632, 'REGISTRATION': 'HL8227'}
# {'ID': 7633, 'REGISTRATION': 'N211MD'}
# {'ID': 7634, 'REGISTRATION': 'OO-DLJ'}
# {'ID': 7635, 'REGISTRATION': 'B-HIB'}
# {'ID': 7636, 'REGISTRATION': 'HL7626'}
# {'ID': 7637, 'REGISTRATION': 'B-16333'}
# {'ID': 7638, 'REGISTRATION': 'I-DUPD'}
# {'ID': 7639, 'REGISTRATION': 'HL8211'}
# {'ID': 7640, 'REGISTRATION': 'HL8211'}
# {'ID': 7641, 'REGISTRATION': 'HL8212'}
# {'ID': 7642, 'REGISTRATION': 58}
# {'ID': 7643, 'REGISTRATION': '9V-SCA'}
# {'ID': 7644, 'REGISTRATION': '9V-SCA'}
# {'ID': 7645, 'REGISTRATION': 'F-GETA'}
# {'ID': 7646, 'REGISTRATION': 'N93101'}
# {'ID': 7647, 'REGISTRATION': 'JA8957'}
# {'ID': 7648, 'REGISTRATION': 'LN-RGL'}
# {'ID': 7649, 'REGISTRATION': 'N101DN'}
# {'ID': 7650, 'REGISTRATION': 'N101DN'}
# {'ID': 7651, 'REGISTRATION': '9V-SKU'}
# {'ID': 7652, 'REGISTRATION': 'HL8212'}
# {'ID': 7653, 'REGISTRATION': 'HL7328'}
# {'ID': 7654, 'REGISTRATION': '9V-SCB'}
# {'ID': 7655, 'REGISTRATION': 'G-VNAP'}
# {'ID': 7656, 'REGISTRATION': 'A6-EYD'}
# {'ID': 7657, 'REGISTRATION': 'A6-EYH'}
# {'ID': 7658, 'REGISTRATION': 'D-AIKJ'}
# {'ID': 7659, 'REGISTRATION': 'D-AIKJ'}
# {'ID': 7660, 'REGISTRATION': 'VT-EVA'}
# {'ID': 7661, 'REGISTRATION': 'VT-EVA'}
# {'ID': 7662, 'REGISTRATION': 'SX-OAB'}
# {'ID': 7663, 'REGISTRATION': 'N101DN'}
# {'ID': 7664, 'REGISTRATION': 'XA-RNQ'}
# {'ID': 7665, 'REGISTRATION': 'B-HUJ'}
# {'ID': 7666, 'REGISTRATION': 'B-HUI'}
# {'ID': 7667, 'REGISTRATION': 'B-HUJ'}
# {'ID': 7668, 'REGISTRATION': 'B-LGA'}
# {'ID': 7669, 'REGISTRATION': 'F-WLXV'}
# {'ID': 7670, 'REGISTRATION': 'JA741A'}
# {'ID': 7671, 'REGISTRATION': 'F-WLXV'}
# {'ID': 7672, 'REGISTRATION': 'JA741A'}
# {'ID': 7673, 'REGISTRATION': 'F-WLXV'}
# {'ID': 7674, 'REGISTRATION': 'JA741A'}
# {'ID': 7675, 'REGISTRATION': 'JA741A'}
# {'ID': 7676, 'REGISTRATION': 'N8702L'}
# {'ID': 7677, 'REGISTRATION': 'N8706W'}
# {'ID': 7678, 'REGISTRATION': 'N8717M'}
# {'ID': 7679, 'REGISTRATION': 'N8702L'}
# {'ID': 7680, 'REGISTRATION': 'N8706W'}
# {'ID': 7681, 'REGISTRATION': 'N8717M'}
# {'ID': 7682, 'REGISTRATION': 'XA-MAG'}
# {'ID': 7683, 'REGISTRATION': 'N927VA'}
# {'ID': 7684, 'REGISTRATION': 'N926VA'}
# {'ID': 7685, 'REGISTRATION': 'N924VA'}
# {'ID': 7686, 'REGISTRATION': 'N925VA'}
# {'ID': 7687, 'REGISTRATION': 'XA-MAG'}
# {'ID': 7688, 'REGISTRATION': 'N927VA'}
# {'ID': 7689, 'REGISTRATION': 'N926VA'}
# {'ID': 7690, 'REGISTRATION': 'N924VA'}
# {'ID': 7691, 'REGISTRATION': 'N925VA'}
# {'ID': 7692, 'REGISTRATION': 'VH-VQS'}
# {'ID': 7693, 'REGISTRATION': 'VH-VQS'}
# {'ID': 7694, 'REGISTRATION': 'VH-VQS'}
# {'ID': 7695, 'REGISTRATION': 'N204HA'}
# {'ID': 7696, 'REGISTRATION': 'C-FRAX'}
# {'ID': 7697, 'REGISTRATION': 'XA-SIB'}
# {'ID': 7698, 'REGISTRATION': 'PP-VMB'}
# {'ID': 7699, 'REGISTRATION': 'YA-LAS'}
# {'ID': 7700, 'REGISTRATION': 'XA-SIB'}
# {'ID': 7701, 'REGISTRATION': 'PP-VMB'}
# {'ID': 7702, 'REGISTRATION': 'YA-LAS'}
# {'ID': 7703, 'REGISTRATION': 'XA-SIB'}
# {'ID': 7704, 'REGISTRATION': 'PP-VMB'}
# {'ID': 7705, 'REGISTRATION': 'B-16331'}
# {'ID': 7706, 'REGISTRATION': 'B-16331'}
# {'ID': 7707, 'REGISTRATION': 'D-AIGZ'}
# {'ID': 7708, 'REGISTRATION': 'OY-GRN'}
# {'ID': 7709, 'REGISTRATION': 'HL7470'}
# {'ID': 7710, 'REGISTRATION': 'HL7465'}
# {'ID': 7711, 'REGISTRATION': 'VR-BDJ'}
# {'ID': 7712, 'REGISTRATION': 'VR-BDJ'}
# {'ID': 7713, 'REGISTRATION': 'VR-BDJ'}
# {'ID': 7714, 'REGISTRATION': 'A7-BFA'}
# {'ID': 7715, 'REGISTRATION': 'VH-VOZ'}
# {'ID': 7716, 'REGISTRATION': 'ZS-SPE'}
# {'ID': 7717, 'REGISTRATION': 'JA8580'}
# {'ID': 7718, 'REGISTRATION': 'C-FCRA'}
# {'ID': 7719, 'REGISTRATION': 'TF-FIR'}
# {'ID': 7720, 'REGISTRATION': 'TF-FIR'}
# {'ID': 7721, 'REGISTRATION': 'TF-FIR'}
# {'ID': 7722, 'REGISTRATION': 'TF-FIR'}
# {'ID': 7723, 'REGISTRATION': 'N511PA'}
# {'ID': 7724, 'REGISTRATION': 'A6-ENJ'}
# {'ID': 7725, 'REGISTRATION': 'N511PA'}
# {'ID': 7726, 'REGISTRATION': 'VH-QOA'}
# {'ID': 7727, 'REGISTRATION': 'N163SY'}
# {'ID': 7728, 'REGISTRATION': 'N605UP'}
# {'ID': 7729, 'REGISTRATION': 'A6-EUG'}
# {'ID': 7730, 'REGISTRATION': 'P-885'}
# {'ID': 7731, 'REGISTRATION': 'N324RA'}
# {'ID': 7732, 'REGISTRATION': 'N823NW'}
# {'ID': 7733, 'REGISTRATION': 'N163SY'}
# {'ID': 7734, 'REGISTRATION': 'N416YX'}
# {'ID': 7735, 'REGISTRATION': 'N651GJ'}
# {'ID': 7736, 'REGISTRATION': 'A6-EUZ'}
# {'ID': 7737, 'REGISTRATION': 'N187US'}
# {'ID': 7738, 'REGISTRATION': 'N708EV'}
# {'ID': 7739, 'REGISTRATION': 'D-ABYM'}
# {'ID': 7740, 'REGISTRATION': 'G-VMIK'}
# {'ID': 7741, 'REGISTRATION': 'JA741A'}
# {'ID': 7742, 'REGISTRATION': 'A7-ALZ'}
# {'ID': 7743, 'REGISTRATION': 'VT-JET'}
# {'ID': 7744, 'REGISTRATION': 'B-LXA'}
# {'ID': 7745, 'REGISTRATION': 'VT-JET'}
# {'ID': 7746, 'REGISTRATION': 'B-LXA'}
# {'ID': 7747, 'REGISTRATION': 'VH-VQS'}
# {'ID': 7748, 'REGISTRATION': 'TF-ICE'}
# {'ID': 7749, 'REGISTRATION': 'TF-ICE'}
# {'ID': 7750, 'REGISTRATION': 'PR-OBD'}
# {'ID': 7751, 'REGISTRATION': 'PR-OBD'}
# {'ID': 7752, 'REGISTRATION': 'N309FR'}
# {'ID': 7753, 'REGISTRATION': 'N309FR'}
# {'ID': 7754, 'REGISTRATION': 'N309FR'}
# {'ID': 7755, 'REGISTRATION': 'N310FR'}
# {'ID': 7756, 'REGISTRATION': 'N310FR'}
# {'ID': 7757, 'REGISTRATION': 'N310FR'}
# {'ID': 7758, 'REGISTRATION': 'N311FR'}
# {'ID': 7759, 'REGISTRATION': 'N311FR'}
# {'ID': 7760, 'REGISTRATION': 'N311FR'}
# {'ID': 7761, 'REGISTRATION': 'OB-1590'}
# {'ID': 7762, 'REGISTRATION': 'XA-HON'}
# {'ID': 7763, 'REGISTRATION': 'OB-1573'}
# {'ID': 7764, 'REGISTRATION': 'N67501'}
# {'ID': 7765, 'REGISTRATION': 'N323FR'}
# {'ID': 7766, 'REGISTRATION': 'D-AISP'}
# {'ID': 7767, 'REGISTRATION': 'OB-1590'}
# {'ID': 7768, 'REGISTRATION': 'XA-HON'}
# {'ID': 7769, 'REGISTRATION': 'OB-1573'}
# {'ID': 7770, 'REGISTRATION': 'N67501'}
# {'ID': 7771, 'REGISTRATION': 'N323FR'}
# {'ID': 7772, 'REGISTRATION': 'D-AISP'}
# {'ID': 7773, 'REGISTRATION': 'OB-1590'}
# {'ID': 7774, 'REGISTRATION': 'XA-HON'}
# {'ID': 7775, 'REGISTRATION': 'OB-1573'}
# {'ID': 7776, 'REGISTRATION': 'N67501'}
# {'ID': 7777, 'REGISTRATION': 'N323FR'}
# {'ID': 7778, 'REGISTRATION': 'HL8227'}
# {'ID': 7779, 'REGISTRATION': 'HL7644'}
# {'ID': 7780, 'REGISTRATION': 'HL7644'}
# {'ID': 7781, 'REGISTRATION': 'B-HOL'}
# {'ID': 7782, 'REGISTRATION': 'G-CIVZ'}
# {'ID': 7783, 'REGISTRATION': 'G-BDXO'}
# {'ID': 7784, 'REGISTRATION': 'XA-PIK'}
# {'ID': 7785, 'REGISTRATION': 'XA-PIK'}
# {'ID': 7786, 'REGISTRATION': 'XA-PIK'}
# {'ID': 7787, 'REGISTRATION': 'N727AA'}
# {'ID': 7788, 'REGISTRATION': 'JA928A'}
# {'ID': 7789, 'REGISTRATION': 'VH-ZND'}
# {'ID': 7790, 'REGISTRATION': 'XA-AMC'}
# {'ID': 7791, 'REGISTRATION': 'JA928A'}
# {'ID': 7792, 'REGISTRATION': 'JA928A'}
# {'ID': 7793, 'REGISTRATION': 'VH-ZND'}
# {'ID': 7794, 'REGISTRATION': 'VH-ZND'}
# {'ID': 7795, 'REGISTRATION': 'XA-AMC'}
# {'ID': 7796, 'REGISTRATION': 'HK-2000'}
# {'ID': 7797, 'REGISTRATION': 'HK-2000'}
# {'ID': 7798, 'REGISTRATION': 'F-HRBB'}
# {'ID': 7799, 'REGISTRATION': 'N836NN'}
# {'ID': 7800, 'REGISTRATION': 'N416YX'}
# {'ID': 7801, 'REGISTRATION': 'N896AT'}
# {'ID': 7802, 'REGISTRATION': 'A6-ENV'}
# {'ID': 7803, 'REGISTRATION': 'N438QX'}
# {'ID': 7804, 'REGISTRATION': 'N704DK'}
# {'ID': 7806, 'REGISTRATION': 'N317FR'}
# {'ID': 7807, 'REGISTRATION': 'N318FR'}
# {'ID': 7808, 'REGISTRATION': 'N928VA'}
# {'ID': 7809, 'REGISTRATION': 'N317FR'}
# {'ID': 7810, 'REGISTRATION': 'N318FR'}
# {'ID': 7811, 'REGISTRATION': 'N928VA'}
# {'ID': 7812, 'REGISTRATION': 'N317FR'}
# {'ID': 7813, 'REGISTRATION': 'N318FR'}
# {'ID': 7814, 'REGISTRATION': 'N928VA'}
# {'ID': 7815, 'REGISTRATION': 'N618US'}
# {'ID': 7816, 'REGISTRATION': 'N7644U'}
# {'ID': 7817, 'REGISTRATION': 'N7644U'}
# {'ID': 7818, 'REGISTRATION': 'N7644U'}
# {'ID': 7819, 'REGISTRATION': 'N1035F'}
# {'ID': 7820, 'REGISTRATION': 'N1035F'}
# {'ID': 7821, 'REGISTRATION': 'N1035F'}
# {'ID': 7822, 'REGISTRATION': 'HB-IFH'}
# {'ID': 7823, 'REGISTRATION': 'N8060U'}
# {'ID': 7824, 'REGISTRATION': '.N8005U'}
# {'ID': 7825, 'REGISTRATION': 'N7131C'}
# {'ID': 7826, 'REGISTRATION': 'N8060U'}
# {'ID': 7827, 'REGISTRATION': '.N8005U'}
# {'ID': 7828, 'REGISTRATION': 'N7131C'}
# {'ID': 7829, 'REGISTRATION': 'N7644U'}
# {'ID': 7830, 'REGISTRATION': 'N7644U'}
# {'ID': 7831, 'REGISTRATION': 'N7644U'}
# {'ID': 7832, 'REGISTRATION': 'HB-IFH'}
# {'ID': 7833, 'REGISTRATION': 'N1838U'}
# {'ID': 7834, 'REGISTRATION': 'PP-VMZ'}
# {'ID': 7835, 'REGISTRATION': 'N68045'}
# {'ID': 7836, 'REGISTRATION': 'N595JB'}
# {'ID': 7837, 'REGISTRATION': 'N1838U'}
# {'ID': 7838, 'REGISTRATION': 'PP-VMZ'}
# {'ID': 7839, 'REGISTRATION': 'N68045'}
# {'ID': 7840, 'REGISTRATION': 'N595JB'}
# {'ID': 7841, 'REGISTRATION': 'N1838U'}
# {'ID': 7842, 'REGISTRATION': 'PP-VMZ'}
# {'ID': 7843, 'REGISTRATION': 'N68045'}
# {'ID': 7844, 'REGISTRATION': 'N595JB'}
# {'ID': 7845, 'REGISTRATION': 'N88715'}
# {'ID': 7846, 'REGISTRATION': 'HK-2151X'}
# {'ID': 7847, 'REGISTRATION': 'HK-2151X'}
# {'ID': 7848, 'REGISTRATION': '\tEI-FYB'}
# {'ID': 7849, 'REGISTRATION': 'EI-FYE'}
# {'ID': 7850, 'REGISTRATION': '\tEI-FYF'}
# {'ID': 7851, 'REGISTRATION': 'N7644U'}
# {'ID': 7852, 'REGISTRATION': 'N7644U'}
# {'ID': 7853, 'REGISTRATION': 'N7644U'}
# {'ID': 7854, 'REGISTRATION': 'JA382A'}
# {'ID': 7855, 'REGISTRATION': 'JA383A'}
# {'ID': 7856, 'REGISTRATION': 'G-VXWB'}
# {'ID': 7857, 'REGISTRATION': 'JA382A'}
# {'ID': 7858, 'REGISTRATION': 'JA383A'}
# {'ID': 7859, 'REGISTRATION': 'JA382A'}
# {'ID': 7860, 'REGISTRATION': 'JA383A'}
# {'ID': 7861, 'REGISTRATION': 'N7370F'}
# {'ID': 7862, 'REGISTRATION': 'N305EA'}
# {'ID': 7863, 'REGISTRATION': '\tD-AICE'}
# {'ID': 7865, 'REGISTRATION': '\tUR-FAA'}
# {'ID': 7866, 'REGISTRATION': 'G-STRX'}
# {'ID': 7867, 'REGISTRATION': 'N1838U'}
# {'ID': 7868, 'REGISTRATION': 'N1838U'}
# {'ID': 7869, 'REGISTRATION': 'N1838U'}
# {'ID': 7870, 'REGISTRATION': 'VT-EXF'}
# {'ID': 7871, 'REGISTRATION': 'VT-EXF'}
# {'ID': 7872, 'REGISTRATION': 'VT-EXF'}
# {'ID': 7873, 'REGISTRATION': 'G-EUYV'}
# {'ID': 7874, 'REGISTRATION': 'G-LCYO'}
# {'ID': 7875, 'REGISTRATION': 'N493AS'}
# {'ID': 7876, 'REGISTRATION': 'N216AG'}
# {'ID': 7877, 'REGISTRATION': 'EC-KAZ'}
# {'ID': 7878, 'REGISTRATION': 'N625VA'}
# {'ID': 7879, 'REGISTRATION': 'G-TTNA'}
# {'ID': 7880, 'REGISTRATION': 'G-XWBA'}
# {'ID': 7881, 'REGISTRATION': 'G-XWBA'}
# {'ID': 7882, 'REGISTRATION': 'G-VXWB'}
# {'ID': 7883, 'REGISTRATION': 'N551NW'}
# {'ID': 7884, 'REGISTRATION': 'A6-EUC'}
# {'ID': 7885, 'REGISTRATION': 'TF-FIR'}
# {'ID': 7886, 'REGISTRATION': 'VH-OQF'}
# {'ID': 7887, 'REGISTRATION': 'N502DN'}
# {'ID': 7888, 'REGISTRATION': 'N904DA'}
# {'ID': 7889, 'REGISTRATION': 'N67501'}
# {'ID': 7890, 'REGISTRATION': 'G-VNAP'}
# {'ID': 7891, 'REGISTRATION': '9V-SMJ'}
# {'ID': 7892, 'REGISTRATION': 'HB-JHR'}
# {'ID': 7893, 'REGISTRATION': 'V8-BKH'}
# {'ID': 7894, 'REGISTRATION': 'N1035F'}
# {'ID': 7895, 'REGISTRATION': 'N1035F'}
# {'ID': 7896, 'REGISTRATION': 'N1035F'}
# {'ID': 7897, 'REGISTRATION': 'SX-CBE'}
# {'ID': 7898, 'REGISTRATION': 'SX-CBI'}
# {'ID': 7899, 'REGISTRATION': 'SX-CBE'}
# {'ID': 7900, 'REGISTRATION': 'SX-CBI'}
# {'ID': 7901, 'REGISTRATION': 'SX-CBE'}
# {'ID': 7902, 'REGISTRATION': 'SX-CBI'}
# {'ID': 7903, 'REGISTRATION': 'EI-FYC'}
# {'ID': 7904, 'REGISTRATION': 'EI-FYA'}
# {'ID': 7905, 'REGISTRATION': 'EI-FYD'}
# {'ID': 7906, 'REGISTRATION': 'XA-MEE'}
# {'ID': 7907, 'REGISTRATION': 'XA-AMD'}
# {'ID': 7908, 'REGISTRATION': 'XA-MEE'}
# {'ID': 7909, 'REGISTRATION': 'XA-AMD'}
# {'ID': 7910, 'REGISTRATION': 'PP-VMY'}
# {'ID': 7911, 'REGISTRATION': 'PP-VMY'}
# {'ID': 7912, 'REGISTRATION': 'PP-VMY'}
# {'ID': 7913, 'REGISTRATION': 'HB-IST'}
# {'ID': 7914, 'REGISTRATION': 'VH-DHE'}
# {'ID': 7915, 'REGISTRATION': 'N235NW'}
# {'ID': 7916, 'REGISTRATION': 'TF-FIR'}
# {'ID': 7917, 'REGISTRATION': 'TF-FIR'}
# {'ID': 7918, 'REGISTRATION': 'TF-FIR'}
# {'ID': 7919, 'REGISTRATION': 'PH-DCS'}
# {'ID': 7920, 'REGISTRATION': 'PH-DCS'}
# {'ID': 7921, 'REGISTRATION': 'N605UP'}
# {'ID': 7922, 'REGISTRATION': 'N605UP'}
# {'ID': 7923, 'REGISTRATION': 'G-AWNF'}
# {'ID': 7924, 'REGISTRATION': 'VP-BVR'}
# {'ID': 7925, 'REGISTRATION': 'N180UA'}
